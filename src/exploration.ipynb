# %% [markdown]
# # Gene Expression Dataset Exploration

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from preprocessing import train_test_val_split
from LR_random_baseline import *

# %%
DATA_PATH = "../data/SCANB.csv"
LABEL_PATH = "../data/sampleinfo_SCANB_t.csv"

# %%
df = pd.read_csv(DATA_PATH)

# %%
TRAIN_PCT = 0.7
VALIDATION_PCT = 0.1
RANDOM_SEED = 2

# %%
df.head()
# Out:
#   Unnamed: 0        F1        F2        F3        F4        F5        F6  \
# 0        A2M -1.098234  0.110096 -1.779393  0.268360  0.616851  3.433406
# 1      A4GNT -0.615048 -0.615048 -0.615048 -0.615048 -0.615048 -0.615048
# 2       AAAS -1.670827  0.248934 -0.422635  0.236302 -0.988261 -1.263231
# 3       AACS -0.539020  0.032084  0.392158  0.563540 -0.083663 -0.748093
# 4      AADAC  0.098325  0.262344 -0.711190 -0.373168  0.067739 -0.711190
#
#          F9       F10       F11  ...  F2841repl  F2860repl  F2872repl  \
# 0 -0.424064  0.357813  0.629575  ...   0.340017  -0.427134  -0.811695
# 1 -0.615048 -0.615048  3.324828  ...   2.004878   0.408918  -0.615048
# 2 -2.147768 -1.700644  0.055263  ...  -0.807723  -1.566462   1.859718
# 3 -0.999103 -1.358139  2.157231  ...   0.241122  -0.216516   0.841555
# 4 -0.711190 -0.183505 -0.021691  ...  -0.711190   2.818603  -0.711190
#
#    F2877repl  F2911repl  F2912repl  F2958repl  F3057repl  F3085repl  F3135repl
# 0   1.155090  -0.873224  -0.186538  -0.071234   1.535495  -2.769459   1.348425
# 1   2.120522  -0.615048   2.274780   0.598461   1.185567  -0.615048  -0.615048
# 2  -1.240860   1.058475  -0.234717  -0.501922   0.165044   0.883363  -1.641798
# 3  -1.019500  -0.108282   0.508552   0.663004  -0.257163  -0.884103   0.819606
# 4  -0.711190  -0.711190  -0.711190  -0.711190  -0.711190  -0.056693  -0.711190
#
# [5 rows x 3070 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9264 entries, 0 to 9263
# Columns: 3070 entries, Unnamed: 0 to F3135repl
# dtypes: float64(3069), object(1)
# memory usage: 217.0+ MB

# %%
labels = pd.read_csv(LABEL_PATH)

# %%
labels.head()
# Out:
#    Unnamed: 0 samplename  ER   PAM50  time  event    Lympho  cluster2
# 0           1         F1   1   Basal  2367      0  2.602223         6
# 1           2         F2   2    LumA  2367      0  1.104544         5
# 2           3         F3   2    LumB  2168      1  0.581018         5
# 3           4         F4   2    LumA  2416      0  2.882004         6
# 4           5         F5   2  Normal  2389      0  1.013356         4

# %%
labels['is_lumA'] = labels.PAM50 == 'LumA'

# %%
labels.head()
# Out:
#    Unnamed: 0 samplename  ER   PAM50  time  event    Lympho  cluster2  is_lumA
# 0           1         F1   1   Basal  2367      0  2.602223         6    False
# 1           2         F2   2    LumA  2367      0  1.104544         5     True
# 2           3         F3   2    LumB  2168      1  0.581018         5    False
# 3           4         F4   2    LumA  2416      0  2.882004         6     True
# 4           5         F5   2  Normal  2389      0  1.013356         4    False

# %%
train, validation, test = train_test_val_split(labels, RANDOM_SEED, TRAIN_PCT, VALIDATION_PCT)

# %%
N_values = [10, 50, 100, 250, 500, 700, 1000, 2500, 3000, 5000, 7000, df.shape[1]-1]
plot_performance_with_stats(df, train, validation, N_values, RANDOM_SEED, num_runs=10, lr_C=np.inf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 N_values = [10, 50, 100, 250, 500, 700, 1000, 2500, 3000, 5000, 7000, df.shape[1]-1]
# ----> 2 plot_performance_with_stats(df, train, validation, N_values, RANDOM_SEED, num_runs=10, lr_C=np.inf)
#
# File ~/feature_selection/feature_selection/src/LR_random_baseline.py:77, in plot_performance_with_stats(gene_expression_df, train_labels_df, val_labels_df, N_values, random_seed, num_runs, lr_C)
#      74 def plot_performance_with_stats(gene_expression_df, train_labels_df, val_labels_df, N_values, random_seed, num_runs, lr_C=np.inf):
#      75     all_runs_results = []
# ---> 77     for run_id in tqdm(range(num_runs), desc="Running experiments"):
#      78         run_results = []
#      79         for n in N_values:
#      80             # Call the train_and_evaluate_logistic_regression function
#
# NameError: name 'tqdm' is not defined
