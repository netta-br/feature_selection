# %% [markdown]
# # Wrapper Feature Selection — Example Notebook
#
# Demonstrates **`WrapperSelector`** on the SCANB gene-expression dataset.
#
# | Task | Target | Type | Algorithm | SU Mode |
# |------|--------|------|-----------|----------|
# | **A** | `is_lumA` | classification | IWSS-MB | Mode A — precomputed SU matrix (with MI interim save) |
# | **B** | `Lympho` | regression | IWSS-MB | Mode A — precomputed SU matrix |
# | **C** | `is_lumA` | classification | all four variants | Mode B — lazy incremental fill |
#
# **Features demonstrated:**
# - `ScoreMatrix` with `method="su"` — replaces `ScoreMatrix`
# - Mode A precomputation (CSV/Parquet load/save) and Mode B lazy `ScoreCalculator` fill
# - `cv_folds` / `cv_min_folds` dual-condition acceptance
# - `mb_threshold` — configurable MB pruning margin (conservative pruning control)
# - `PATIENCE` stopping (global, default `None`)
# - `test_eval_every_k` validation evaluation
# - SU statistics exploration (feature–target, feature–feature, and pruning‐margin distributions)
# - `WrapperSelectionResult` timing breakdown
# - `SelectionResult.compare_results` for multi-algorithm comparison
# - `SelectionResult.compare_with` for pairwise rank-aligned feature diff
# - `SelectionResult.summary_report` for multi-result feature summary
# - `plot_vs_random_baseline` for classification and regression

# %% [markdown]
# ## 0 — Imports & paths

# %%
import sys, os

# Make sure the package root is on the path when running from feature_selection/src/
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from feature_selection.src.preprocessing import train_test_val_split
from feature_selection.src.score_matrix import ScoreMatrix
from feature_selection.src.wrapper.MarkovBlanketWrapper import WrapperSelector
from feature_selection.src.results import SelectionResult, WrapperSelectionResult
from feature_selection.src.baseline.logistic_regression_random_baseline import plot_performance_with_stats as clf_baseline_plot
from feature_selection.src.baseline.linear_regression_random_baseline import plot_performance_with_stats as reg_baseline_plot

# ── Paths (relative to notebook location: feature_selection/src/) ──────────
DATA_PATH  = '../data/SCANB.csv'
LABEL_PATH = '../data/sampleinfo_SCANB_t.csv'

# Precomputed SU matrix — single file shared across all tasks on the same feature set
# Feature-pair SU values are target-independent; only the target column differs.
SU_PATH = '../data/su_matrix.csv'   # shared SU matrix (features + all targets)

# ── Globals ────────────────────────────────────────────────────────────────
RANDOM_SEED     = 2
N_FEATURES      = 20    # features to select
TEST_EVAL_EVERY = 2     # run test/val evaluation every k selections
N_RUNS          = 10    # random baseline runs
CV_FOLDS        = 5
CV_MIN_FOLDS    = 3
PATIENCE        = None  # stop after N consecutive non-improvements; None = no limit
MB_THRESHOLD    = 1e-2   # MB pruning margin; 0.0 = original Definition 5; positive = more conservative

# %% [markdown]
# ## 1 — Load data & build train / validation splits

# %%
gene_expression_df = pd.read_csv(DATA_PATH)
sampleinfo_df      = pd.read_csv(LABEL_PATH)

# Binary LumA label
sampleinfo_df['is_lumA'] = (sampleinfo_df['PAM50'] == 'LumA').astype(int)

# 70% train / 10% val / 20% test
train_si, val_si, _ = train_test_val_split(
    sampleinfo_df, random_seed=RANDOM_SEED, train_pcnt=0.7, val_pct=0.1
)

train_labels_df = train_si[['samplename', 'is_lumA']].reset_index(drop=True)
val_labels_df   = val_si[['samplename', 'is_lumA']].reset_index(drop=True)

print(f'Train samples : {len(train_labels_df)}')
print(f'Val   samples : {len(val_labels_df)}')
print(f"LumA prevalence (train): {train_labels_df['is_lumA'].mean():.2%}")

# Transpose gene-expression (genes × samples) → (samples × genes)
ge_proc = gene_expression_df.copy().fillna(0).set_index('Unnamed: 0').T
ge_proc.index.name = 'samplename'

X_train = ge_proc.loc[train_labels_df['samplename']]
X_val   = ge_proc.loc[val_labels_df['samplename']]

print(f'\nX_train shape : {X_train.shape}')
print(f'X_val   shape : {X_val.shape}')
# Out:
# Train samples : 2148
# Val   samples : 306
# LumA prevalence (train): 49.30%
#
# X_train shape : (2148, 9264)
# X_val   shape : (306, 9264)

# %% [markdown]
# ## 2 — Build target series

# %%
# Classification target: is_lumA
y_lumA = (
    train_labels_df.set_index('samplename')['is_lumA']
    .reindex(X_train.index)
)  # Series.name == 'is_lumA'

y_lumA_val = (
    val_labels_df.set_index('samplename')['is_lumA']
    .reindex(X_val.index)
)

# Regression target: Lympho
y_lympho = (
    sampleinfo_df.set_index('samplename')['Lympho']
    .reindex(X_train.index)
)  # Series.name == 'Lympho'

y_lympho_val = (
    sampleinfo_df.set_index('samplename')['Lympho']
    .reindex(X_val.index)
)

print(f'y_lumA   name={y_lumA.name!r}    dtype={y_lumA.dtype}   nunique={y_lumA.nunique()}')
print(f'y_lympho name={y_lympho.name!r}  dtype={y_lympho.dtype}   nunique={y_lympho.nunique()}')
# Out:
# y_lumA   name='is_lumA'    dtype=int64   nunique=2
# y_lympho name='Lympho'  dtype=float64   nunique=2148

# %% [markdown]
# ---
#
# ## Precomputation — SU matrix (Mode A)
#
# **Run once** to compute and save the full Symmetric Uncertainty matrix.
# On subsequent runs the file is loaded directly — no recomputation.
#
# The new `ScoreMatrix` class with `method='su'` replaces the old
# precomputation classes.  It uses `ScoreCalculator`
# internally with the fully vectorised `np.bincount`-based SU engine.
#
# > **Single shared matrix**
# > Feature-pair SU values are identical regardless of which target is used, so
# > there is no reason to recompute them for every task.  We build **one** matrix
# > that includes both target columns (`is_lumA` and `Lympho`).

# %% [markdown]
# ### Precompute shared SU matrix (both targets: `is_lumA` and `Lympho`)
#
# Uses `ScoreMatrix(method='su')` — the new vectorised SU engine.

# %%
if not os.path.exists(SU_PATH):
    print('Computing shared SU matrix for both targets...')
    print(f'  SU matrix → {SU_PATH}')
    ScoreMatrix(
        X=X_train.fillna(0).values,
        feature_names=list(X_train.columns),
        target_names=[str(y_lumA.name), str(y_lympho.name)],
        target_data=pd.concat([y_lumA, y_lympho], axis=1).fillna(0).values,
        method='su',
        filepath=SU_PATH,
        file_format='csv',
    ).precompute()
else:
    print(f'SU matrix already exists at {SU_PATH} — skipping computation.')

# Inspect the saved SU matrix
if os.path.exists(SU_PATH):
    su_shared = pd.read_csv(SU_PATH, index_col=0)
    print(f'\nShared SU matrix shape: {su_shared.shape}')
    if 'is_lumA' in su_shared.columns:
        print('Top-5 SU values with is_lumA target:')
        print(su_shared['is_lumA'].drop('is_lumA', errors='ignore').sort_values(ascending=False).head(5).to_string())
    if 'Lympho' in su_shared.columns:
        print('\nTop-5 SU values with Lympho target:')
        print(su_shared['Lympho'].drop('Lympho', errors='ignore').sort_values(ascending=False).head(5).to_string())
# Out:
# SU matrix already exists at ../data/su_matrix.csv — skipping computation.
#
# Shared SU matrix shape: (9266, 9266)
# Top-5 SU values with is_lumA target:
# MYBL2    0.267609
# CDC45    0.258247
# BIRC5    0.257759
# CCNB2    0.253082
# PTTG1    0.250041
#
# Top-5 SU values with Lympho target:
# CD247    0.586616
# IL2RG    0.586565
# ACAP1    0.584904
# LCK      0.581479
# CD3E     0.575799

# %% [markdown]
# ---
#
# ## SU Statistics Exploration
#
# Inspect the distribution of feature–feature and feature–target Symmetric
# Uncertainty values from the precomputed matrix.  Understanding these
# distributions helps choose a sensible `mb_threshold` and explains how
# aggressively MB pruning will act.

# %% [markdown]
# ### Feature–target SU distribution

# %%
# Load shared SU matrix (must have been computed in the Precomputation section)
su_df = pd.read_csv(SU_PATH, index_col=0)

# Feature names = everything that is NOT a target column
target_cols = ['is_lumA', 'Lympho']
feature_names = [c for c in su_df.columns if c not in target_cols]

fig, axes = plt.subplots(1, len(target_cols), figsize=(7 * len(target_cols), 5))
if len(target_cols) == 1:
    axes = [axes]

for ax, tgt in zip(axes, target_cols):
    if tgt not in su_df.columns:
        ax.set_title(f'{tgt} — not in matrix'); continue
    su_ft = su_df.loc[feature_names, tgt].dropna()
    ax.hist(su_ft.values, bins=80, color='steelblue', edgecolor='white', alpha=0.85)
    ax.axvline(su_ft.median(), color='red', ls='--', lw=1.2, label=f'median={su_ft.median():.4f}')
    ax.axvline(su_ft.mean(),   color='orange', ls='--', lw=1.2, label=f'mean={su_ft.mean():.4f}')
    ax.set_xlabel('SU(feature, target)')
    ax.set_ylabel('Count')
    ax.set_title(f'SU(feature, {tgt})  —  {len(su_ft)} features')
    ax.legend(fontsize=9)
    ax.grid(True, alpha=0.3)

fig.suptitle('Feature–Target SU distributions', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

for tgt in target_cols:
    if tgt not in su_df.columns: continue
    su_ft = su_df.loc[feature_names, tgt].dropna()
    print(f'\n{tgt}:')
    print(su_ft.describe().to_string())
# Out:
# is_lumA:
# count    9264.000000
# mean        0.028684
# std         0.030824
# min         0.000000
# 25%         0.008887
# 50%         0.019326
# 75%         0.038502
# max         0.267609
#
# Lympho:
# count    9264.000000
# mean        0.026890
# std         0.058069
# min         0.000000
# 25%         0.004415
# 50%         0.010493
# 75%         0.022935
# max         0.586616

# %% [markdown]
# ### Feature–feature SU distribution

# %%
# Extract upper triangle of feature–feature SU (excluding diagonal)
su_ff = su_df.loc[feature_names, feature_names].values
iu = np.triu_indices(len(feature_names), k=1)
ff_values = su_ff[iu]

print(f'Feature–feature pairs: {len(ff_values):,}')
print(f'  min    = {ff_values.min():.6f}')
print(f'  max    = {ff_values.max():.6f}')
print(f'  mean   = {ff_values.mean():.6f}')
print(f'  median = {np.median(ff_values):.6f}')
print(f'  std    = {ff_values.std():.6f}')

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax = axes[0]
ax.hist(ff_values, bins=100, color='teal', edgecolor='white', alpha=0.85)
ax.axvline(np.median(ff_values), color='red', ls='--', lw=1.2, label=f'median={np.median(ff_values):.4f}')
ax.axvline(ff_values.mean(), color='orange', ls='--', lw=1.2, label=f'mean={ff_values.mean():.4f}')
ax.set_xlabel('SU(F_i, F_j)')
ax.set_ylabel('Count')
ax.set_title('Feature–Feature SU distribution (all pairs)')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.3)

# Zoom into the tail (top 5%)
ax = axes[1]
p95 = np.percentile(ff_values, 95)
tail = ff_values[ff_values >= p95]
ax.hist(tail, bins=60, color='coral', edgecolor='white', alpha=0.85)
ax.axvline(p95, color='grey', ls=':', lw=1, label=f'P95={p95:.4f}')
ax.set_xlabel('SU(F_i, F_j)')
ax.set_ylabel('Count')
ax.set_title(f'Top 5% tail (SU \u2265 {p95:.4f})  —  {len(tail):,} pairs')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.3)

fig.suptitle('Feature–Feature SU statistics', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Feature–feature pairs: 42,906,216
#   min    = 0.000000
#   max    = 0.712186
#   mean   = 0.013165
#   median = 0.007049
#   std    = 0.019374

# %% [markdown]
# ### MB pruning margin analysis
#
# For each feature pair where $SU(F_i, C) \ge SU(F_j, C)$ (the first
# MB condition), compute the margin $SU(F_i, F_j) - SU(F_j, C)$.
# Only positive margins trigger pruning under `mb_threshold=0`.
# The distribution of these margins shows what threshold values would
# meaningfully reduce pruning.

# %%
# Compute MB pruning margins for is_lumA target
tgt = 'is_lumA'
if tgt in su_df.columns:
    su_fC = su_df.loc[feature_names, tgt].values  # SU(f, C) for each feature
    su_ff_mat = su_df.loc[feature_names, feature_names].values

    # For each pair (i, j) where SU(F_i, C) >= SU(F_j, C):
    # margin = SU(F_i, F_j) - SU(F_j, C)
    margins = []
    n = len(feature_names)
    for i in range(n):
        for j in range(n):
            if i == j: continue
            if su_fC[i] >= su_fC[j]:
                margin = su_ff_mat[i, j] - su_fC[j]
                if margin > 0:  # only positive margins (would be pruned at threshold=0)
                    margins.append(margin)

    margins = np.array(margins)
    print(f'Positive pruning margins (target={tgt}): {len(margins):,}')
    if len(margins) > 0:
        print(f'  min    = {margins.min():.6f}')
        print(f'  max    = {margins.max():.6f}')
        print(f'  mean   = {margins.mean():.6f}')
        print(f'  median = {np.median(margins):.6f}')
        for pct in [25, 50, 75, 90, 95, 99]:
            print(f'  P{pct:02d}    = {np.percentile(margins, pct):.6f}')

        fig, ax = plt.subplots(figsize=(10, 5))
        ax.hist(margins, bins=100, color='mediumpurple', edgecolor='white', alpha=0.85)
        ax.axvline(np.median(margins), color='red', ls='--', lw=1.2, label=f'median={np.median(margins):.4f}')
        ax.set_xlabel('Pruning margin: SU(F_i, F_j) − SU(F_j, C)')
        ax.set_ylabel('Count')
        ax.set_title(f'MB pruning margins (target={tgt}) — {len(margins):,} prunable pairs at threshold=0')
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
else:
    print(f'{tgt} not found in SU matrix.')
# Out:
# Positive pruning margins (target=is_lumA): 17,059,264
#   min    = 0.000000
#   max    = 0.680706
#   mean   = 0.012548
#   median = 0.005601
#   P25    = 0.001818
#   P50    = 0.005601
#   P75    = 0.014621
#   P90    = 0.030400
#   P95    = 0.045884
#   P99    = 0.104367

# %% [markdown]
# ---
#
# ## Task A — Classification (is_lumA), IWSS-MB, Mode A

# %% [markdown]
# ### A.1 — Run IWSS-MB selector

# %%
ws_clf = WrapperSelector(
    X_train=X_train,
    y_train=y_lumA,
    X_val=X_val,
    y_val=y_lumA_val,
    use_su_ranking=True,          # IWSS: rank by SU(f, C) descending
    use_mb_pruning=True,          # MB: prune redundant candidates after each selection
    mb_threshold=MB_THRESHOLD,    # MB pruning margin (0.0 = original paper)
    cv_folds=CV_FOLDS,
    cv_min_folds=CV_MIN_FOLDS,
    patience=PATIENCE,
    su_filepath=SU_PATH,          # Mode A: shared SU matrix (feature-pairs computed once)
    random_seed=RANDOM_SEED,
)

result_clf: WrapperSelectionResult = ws_clf.run(
    n_features_to_select=N_FEATURES,
    test_eval_every_k=TEST_EVAL_EVERY,
)

print()
print(result_clf)
# Out:
# 2026-04-12 20:44:58,412 [INFO] ScoreMatrix: Loaded score matrix from ../data/su_matrix.csv (9266×9266, 85840225 valid entries)
# 2026-04-12 20:44:59,128 [INFO] WrapperSelector: Filter init done in 20.761s | SU target col filled | Mode A | top candidate: MYBL2 (SU=0.2676)
# 2026-04-12 20:44:59,130 [INFO] WrapperSelector: WrapperSelector initialised | task=classification | use_su_ranking=True | use_mb_pruning=True | mb_threshold=0.0100 | cv_folds=5 | cv_min_folds=3 | patience=None | n_candidates=9264
# 2026-04-12 20:44:59,156 [INFO] WrapperSelector: Step 1 (IWSS): selected 'MYBL2' mean_cv=0.8087 n_improved=5
# 2026-04-12 20:44:59,162 [INFO] WrapperSelector:   MB pruned 1707 candidates
# 2026-04-12 20:44:59,185 [INFO] WrapperSelector: Step 2 (IWSS): selected 'MAPT' mean_cv=0.8357 n_improved=5
# 2026-04-12 20:44:59,190 [INFO] WrapperSelector:   MB pruned 1911 candidates
# 2026-04-12 20:44:59,215 [DEBUG] WrapperSelector:   Candidate 'CACNA1D' rejected (mean=0.8352 n_imp=2 streak=1)
# 2026-04-12 20:44:59,229 [INFO] WrapperSelector:   Test eval step 2 — accuracy: 0.8137
# 2026-04-12 20:44:59,256 [INFO] WrapperSelector: Step 3 (IWSS): selected 'SCN2B' mean_cv=0.8426 n_improved=4
# 2026-04-12 20:44:59,262 [INFO] WrapperSelector:   MB pruned 1858 candidates
# 2026-04-12 20:44:59,290 [DEBUG] WrapperSelector:   Candidate 'PTPRT' rejected (mean=0.8440 n_imp=2 streak=1)
# 2026-04-12 20:44:59,315 [DEBUG] WrapperSelector:   Candidate 'FYCO1' rejected (mean=0.8440 n_imp=2 streak=2)
# 2026-04-12 20:44:59,338 [DEBUG] WrapperSelector:   Candidate 'RANBP1' rejected (mean=0.8389 n_imp=3 streak=3)
# 2026-04-12 20:44:59,363 [INFO] WrapperSelector: Step 4 (IWSS): selected 'MATN3' mean_cv=0.8464 n_improved=3
# 2026-04-12 20:44:59,368 [INFO] WrapperSelector:   MB pruned 140 candidates
# 2026-04-12 20:44:59,395 [DEBUG] WrapperSelector:   Candidate 'ARHGAP35' rejected (mean=0.8459 n_imp=3 streak=1)
# 2026-04-12 20:44:59,410 [INFO] WrapperSelector:   Test eval step 4 — accuracy: 0.8268
# 2026-04-12 20:44:59,435 [INFO] WrapperSelector: Step 5 (IWSS): selected 'ALAD' mean_cv=0.8468 n_improved=3
# 2026-04-12 20:44:59,438 [INFO] WrapperSelector:   MB pruned 310 candidates
# 2026-04-12 20:44:59,463 [DEBUG] WrapperSelector:   Candidate 'SIRT3' rejected (mean=0.8454 n_imp=3 streak=1)
# 2026-04-12 20:44:59,488 [INFO] WrapperSelector: Step 6 (IWSS): selected 'RAI2' mean_cv=0.8473 n_improved=3
# 2026-04-12 20:44:59,491 [INFO] WrapperSelector:   MB pruned 61 candidates
# 2026-04-12 20:44:59,517 [INFO] WrapperSelector: Step 7 (IWSS): selected 'JMJD6' mean_cv=0.8492 n_improved=3
# 2026-04-12 20:44:59,520 [INFO] WrapperSelector:   MB pruned 115 candidates
# 2026-04-12 20:44:59,548 [INFO] WrapperSelector: Step 8 (IWSS): selected 'DOCK1' mean_cv=0.8492 n_improved=3
# 2026-04-12 20:44:59,552 [INFO] WrapperSelector:   MB pruned 403 candidates
# 2026-04-12 20:44:59,580 [DEBUG] WrapperSelector:   Candidate 'TOM1L2' rejected (mean=0.8450 n_imp=2 streak=1)
# 2026-04-12 20:44:59,599 [INFO] WrapperSelector:   Test eval step 8 — accuracy: 0.8301
# 2026-04-12 20:44:59,623 [DEBUG] WrapperSelector:   Candidate 'RUNX1' rejected (mean=0.8464 n_imp=3 streak=2)
# 2026-04-12 20:44:59,648 [INFO] WrapperSelector: Step 9 (IWSS): selected 'UQCRH' mean_cv=0.8496 n_improved=3
# 2026-04-12 20:44:59,651 [INFO] WrapperSelector:   MB pruned 115 candidates
# 2026-04-12 20:44:59,678 [INFO] WrapperSelector: Step 10 (IWSS): selected 'IGFALS' mean_cv=0.8520 n_improved=3
# 2026-04-12 20:44:59,681 [INFO] WrapperSelector:   MB pruned 123 candidates
# 2026-04-12 20:44:59,705 [DEBUG] WrapperSelector:   Candidate 'GLT8D1' rejected (mean=0.8524 n_imp=2 streak=1)
# 2026-04-12 20:44:59,722 [INFO] WrapperSelector:   Test eval step 10 — accuracy: 0.8366
# 2026-04-12 20:44:59,746 [DEBUG] WrapperSelector:   Candidate 'TDO2' rejected (mean=0.8529 n_imp=2 streak=2)
# 2026-04-12 20:44:59,772 [DEBUG] WrapperSelector:   Candidate 'PTGER3' rejected (mean=0.8510 n_imp=3 streak=3)
# 2026-04-12 20:44:59,797 [DEBUG] WrapperSelector:   Candidate 'SEZ6L' rejected (mean=0.8506 n_imp=2 streak=4)
# 2026-04-12 20:44:59,825 [DEBUG] WrapperSelector:   Candidate 'WDR78' rejected (mean=0.8510 n_imp=2 streak=5)
# 2026-04-12 20:44:59,850 [INFO] WrapperSelector: Step 11 (IWSS): selected 'TIGD6' mean_cv=0.8534 n_improved=3
# 2026-04-12 20:44:59,854 [INFO] WrapperSelector:   MB pruned 272 candidates
# 2026-04-12 20:44:59,880 [DEBUG] WrapperSelector:   Candidate 'ASNS' rejected (mean=0.8520 n_imp=3 streak=1)
# 2026-04-12 20:44:59,904 [DEBUG] WrapperSelector:   Candidate 'MTHFR' rejected (mean=0.8529 n_imp=4 streak=2)
# 2026-04-12 20:44:59,930 [DEBUG] WrapperSelector:   Candidate 'PIR' rejected (mean=0.8501 n_imp=2 streak=3)
# 2026-04-12 20:44:59,954 [INFO] WrapperSelector: Step 12 (IWSS): selected 'KLHL9' mean_cv=0.8538 n_improved=3
# 2026-04-12 20:44:59,957 [INFO] WrapperSelector:   MB pruned 96 candidates
# 2026-04-12 20:44:59,986 [DEBUG] WrapperSelector:   Candidate 'POU4F1' rejected (mean=0.8533 n_imp=3 streak=1)
# 2026-04-12 20:45:00,002 [INFO] WrapperSelector:   Test eval step 12 — accuracy: 0.8366
# 2026-04-12 20:45:00,034 [DEBUG] WrapperSelector:   Candidate 'DEK' rejected (mean=0.8482 n_imp=1 streak=2)
# 2026-04-12 20:45:00,063 [INFO] WrapperSelector: Step 13 (IWSS): selected 'ARHGEF38' mean_cv=0.8557 n_improved=3
# 2026-04-12 20:45:00,066 [INFO] WrapperSelector:   MB pruned 103 candidates
# 2026-04-12 20:45:00,094 [DEBUG] WrapperSelector:   Candidate 'ZNF219' rejected (mean=0.8547 n_imp=2 streak=1)
# 2026-04-12 20:45:00,124 [INFO] WrapperSelector: Step 14 (IWSS): selected 'BTD' mean_cv=0.8571 n_improved=3
# 2026-04-12 20:45:00,127 [INFO] WrapperSelector:   MB pruned 48 candidates
# 2026-04-12 20:45:00,154 [DEBUG] WrapperSelector:   Candidate 'ZBTB40' rejected (mean=0.8557 n_imp=3 streak=1)
# 2026-04-12 20:45:00,169 [INFO] WrapperSelector:   Test eval step 14 — accuracy: 0.8333
# 2026-04-12 20:45:00,199 [DEBUG] WrapperSelector:   Candidate 'SPTAN1' rejected (mean=0.8566 n_imp=3 streak=2)
# 2026-04-12 20:45:00,228 [DEBUG] WrapperSelector:   Candidate 'SLC44A4' rejected (mean=0.8561 n_imp=2 streak=3)
# 2026-04-12 20:45:00,261 [DEBUG] WrapperSelector:   Candidate 'NBEA' rejected (mean=0.8561 n_imp=2 streak=4)
# 2026-04-12 20:45:00,291 [DEBUG] WrapperSelector:   Candidate 'ATP7B' rejected (mean=0.8557 n_imp=3 streak=5)
# 2026-04-12 20:45:00,322 [DEBUG] WrapperSelector:   Candidate 'HPSE' rejected (mean=0.8547 n_imp=1 streak=6)
# 2026-04-12 20:45:00,352 [DEBUG] WrapperSelector:   Candidate 'CCNG2' rejected (mean=0.8543 n_imp=1 streak=7)
# 2026-04-12 20:45:00,381 [DEBUG] WrapperSelector:   Candidate 'TBC1D17' rejected (mean=0.8561 n_imp=2 streak=8)
# 2026-04-12 20:45:00,411 [DEBUG] WrapperSelector:   Candidate 'ME2' rejected (mean=0.8529 n_imp=1 streak=9)
# 2026-04-12 20:45:00,444 [DEBUG] WrapperSelector:   Candidate 'PCSK6' rejected (mean=0.8552 n_imp=3 streak=10)
# 2026-04-12 20:45:00,473 [INFO] WrapperSelector: Step 15 (IWSS): selected 'ARHGAP32' mean_cv=0.8580 n_improved=3
# 2026-04-12 20:45:00,476 [INFO] WrapperSelector:   MB pruned 26 candidates
# 2026-04-12 20:45:00,508 [DEBUG] WrapperSelector:   Candidate 'PDIA6' rejected (mean=0.8571 n_imp=3 streak=1)
# 2026-04-12 20:45:00,539 [DEBUG] WrapperSelector:   Candidate 'RERE' rejected (mean=0.8566 n_imp=2 streak=2)
# 2026-04-12 20:45:00,567 [DEBUG] WrapperSelector:   Candidate 'AARS' rejected (mean=0.8580 n_imp=2 streak=3)
# 2026-04-12 20:45:00,597 [DEBUG] WrapperSelector:   Candidate 'BTG2' rejected (mean=0.8575 n_imp=3 streak=4)
# 2026-04-12 20:45:00,625 [DEBUG] WrapperSelector:   Candidate 'TMSB15A' rejected (mean=0.8585 n_imp=2 streak=5)
# 2026-04-12 20:45:00,653 [INFO] WrapperSelector: Step 16 (IWSS): selected 'SLC25A13' mean_cv=0.8599 n_improved=3
# 2026-04-12 20:45:00,655 [INFO] WrapperSelector:   MB pruned 46 candidates
# 2026-04-12 20:45:00,684 [INFO] WrapperSelector: Step 17 (IWSS): selected 'TBC1D19' mean_cv=0.8603 n_improved=3
# 2026-04-12 20:45:00,686 [INFO] WrapperSelector:   MB pruned 11 candidates
# 2026-04-12 20:45:00,718 [DEBUG] WrapperSelector:   Candidate 'IMPA2' rejected (mean=0.8575 n_imp=2 streak=1)
# 2026-04-12 20:45:00,749 [DEBUG] WrapperSelector:   Candidate 'DUSP4' rejected (mean=0.8589 n_imp=2 streak=2)
# 2026-04-12 20:45:00,778 [INFO] WrapperSelector: Step 18 (IWSS): selected 'TECPR2' mean_cv=0.8617 n_improved=3
# 2026-04-12 20:45:00,782 [INFO] WrapperSelector:   MB pruned 21 candidates
# 2026-04-12 20:45:00,814 [DEBUG] WrapperSelector:   Candidate 'ENO1' rejected (mean=0.8613 n_imp=2 streak=1)
# 2026-04-12 20:45:00,832 [INFO] WrapperSelector:   Test eval step 18 — accuracy: 0.8399
# 2026-04-12 20:45:00,861 [INFO] WrapperSelector: Step 19 (IWSS): selected 'VIPR2' mean_cv=0.8617 n_improved=3
# 2026-04-12 20:45:00,863 [INFO] WrapperSelector:   MB pruned 48 candidates
# 2026-04-12 20:45:00,893 [DEBUG] WrapperSelector:   Candidate 'PPP1R3C' rejected (mean=0.8585 n_imp=2 streak=1)
# 2026-04-12 20:45:00,921 [DEBUG] WrapperSelector:   Candidate 'WDTC1' rejected (mean=0.8603 n_imp=3 streak=2)
# 2026-04-12 20:45:00,950 [INFO] WrapperSelector: Step 20 (IWSS): selected 'GARS' mean_cv=0.8622 n_improved=3
# 2026-04-12 20:45:00,952 [INFO] WrapperSelector:   MB pruned 39 candidates
# 2026-04-12 20:45:00,953 [INFO] WrapperSelector: Selection complete: 20 features | reason=max_features_reached | total_time=22.582s (filter=20.761s clf=1.569s test=0.109s) | cv_evals=59 pruned=7453 skipped=7453
#
# SelectionResult:
#   label             : IWSS-MB
#   features selected : 20
#   task type         : classification
#   stopping reason   : max_features_reached
#   selection time    : 22.582s
#   evaluation time   : 0.109s
#   final accuracy    : 0.8398692810457516
#   final macro F1    : 0.8395797447227363
#   features          : ['MYBL2', 'MAPT', 'SCN2B', 'MATN3', 'ALAD', 'RAI2', 'JMJD6', 'DOCK1', 'UQCRH', 'IGFALS', 'TIGD6', 'KLHL9', 'ARHGEF38', 'BTD', 'ARHGAP32', 'SLC25A13', 'TBC1D19', 'TECPR2', 'VIPR2', 'GARS']
#   filter time         : 20.761s
#   classifier time     : 1.569s
#   test eval time      : 0.109s
#   wrapper evaluations : 59
#   candidates pruned   : 7453
#   evaluations skipped : 7453

# %% [markdown]
# ### A.2 — Timing breakdown

# %%
print('Timing breakdown:')
print(f'  Total selection time   : {result_clf.selection_time_seconds:.3f}s')
print(f'    └─ Filter init time  : {result_clf.filter_time_seconds:.3f}s')
print(f'    └─ Evaluator CV time : {result_clf.classifier_time_seconds:.3f}s')
print(f'  Test eval time (val)   : {result_clf.test_evaluation_time_seconds:.3f}s')
print(f'\nWrapper CV evaluations   : {result_clf.n_wrapper_evaluations}')
print(f'Candidates pruned (MB)   : {result_clf.n_candidates_pruned}')
print(f'Evaluations skipped (MB) : {result_clf.n_evaluations_skipped}')
print(f'Stopping reason          : {result_clf.stopping_reason}')
# Out:
# Timing breakdown:
#   Total selection time   : 22.582s
#     └─ Filter init time  : 20.761s
#     └─ Evaluator CV time : 1.569s
#   Test eval time (val)   : 0.109s
#
# Wrapper CV evaluations   : 59
# Candidates pruned (MB)   : 7453
# Evaluations skipped (MB) : 7453
# Stopping reason          : max_features_reached

# %% [markdown]
# ### A.3 — Selected features

# %%
print(f'Classification — {len(result_clf.selected_features)} features selected (in order):')
for i, f in enumerate(result_clf.selected_features, 1):
    print(f'  {i:2d}. {f}')

# Inspect first history entry — includes 'step' key
if result_clf.performance_history:
    print('\nFirst performance history entry:')
    display(pd.Series({
        k: v for k, v in result_clf.performance_history[0].items()
        if k not in ('macro avg', 'weighted avg')
    }))
# Out:
# Classification — 20 features selected (in order):
#    1. MYBL2
#    2. MAPT
#    3. SCN2B
#    4. MATN3
#    5. ALAD
#    6. RAI2
#    7. JMJD6
#    8. DOCK1
#    9. UQCRH
#   10. IGFALS
#   11. TIGD6
#   12. KLHL9
#   13. ARHGEF38
#   14. BTD
#   15. ARHGAP32
#   16. SLC25A13
#   17. TBC1D19
#   18. TECPR2
#   19. VIPR2
#   20. GARS
#
# First performance history entry:
# 0           {'precision': 0.815068493150685, 'recall': 0.7...
# 1           {'precision': 0.8125, 'recall': 0.828025477707...
# accuracy                                             0.813725
# step                                                        2
# dtype: object

# %% [markdown]
# ### A.4 — LR random baseline

# %%
# N_values = number of features selected at each evaluated checkpoint (NOT a loop index)
checkpoints_clf = [entry['step'] for entry in result_clf.performance_history]

baseline_summary_clf = clf_baseline_plot(
    X_train=X_train,
    y_train=y_lumA,
    X_val=X_val,
    y_val=y_lumA_val,
    N_values=checkpoints_clf,
    random_seed=RANDOM_SEED,
    num_runs=N_RUNS,
    return_summary=True,
)
# Out:
# Running experiments: 100%|██████████| 10/10 [00:24<00:00,  2.50s/it]
# Summary Statistics (Mean +/- Std Dev):
#     features_num   variable      mean       std
# 0              2   f1-score  0.604881  0.034663
# 1              2  precision  0.605392  0.034584
# 2              2     recall  0.605198  0.034504
# 3              4   f1-score  0.645082  0.050261
# 4              4  precision  0.646274  0.050569
# 5              4     recall  0.645441  0.049934
# 6              8   f1-score  0.701096  0.044530
# 7              8  precision  0.701944  0.044669
# 8              8     recall  0.701233  0.044637
# 9             10   f1-score  0.715280  0.048491
# 10            10  precision  0.716583  0.048612
# 11            10     recall  0.715332  0.048342
# 12            12   f1-score  0.733422  0.046414
# 13            12  precision  0.735206  0.045884
# 14            12     recall  0.733525  0.046252
# 15            14   f1-score  0.739194  0.041332
# 16            14  precision  0.741204  0.040252
# 17            14     recall  0.739292  0.041151
# 18            18   f1-score  0.750495  0.030141
# 19            18  precision  0.752270  0.029107
# 20            18     recall  0.750547  0.029997

# %% [markdown]
# ### A.5 — Comparison plot

# %%
result_clf.plot_vs_random_baseline(
    baseline_summary=baseline_summary_clf,
    title_suffix=' — SCANB IWSS-MB (is_lumA)',
)
# Out:
# Summary Statistics — Random Baseline (Mean ± Std):
#    features_num  acc_mean   acc_std   f1_mean    f1_std
# 0             2  0.605229  0.034715  0.604881  0.034663
# 1             4  0.645752  0.050538  0.645082  0.050261
# 2             8  0.701634  0.044411  0.701096  0.044530
# 3            10  0.716013  0.048434  0.715280  0.048491
# 4            12  0.734314  0.046012  0.733422  0.046414
# 5            14  0.740196  0.040708  0.739194  0.041332
# 6            18  0.751307  0.029651  0.750495  0.030141

# %% [markdown]
# ---
#
# ## Task B — Regression (Lympho), IWSS-MB, Mode A

# %% [markdown]
# ### B.1 — Run IWSS-MB selector

# %%
ws_reg = WrapperSelector(
    X_train=X_train,
    y_train=y_lympho,
    X_val=X_val,
    y_val=y_lympho_val,
    use_su_ranking=True,
    use_mb_pruning=True,
    mb_threshold=MB_THRESHOLD,
    cv_folds=CV_FOLDS,
    cv_min_folds=CV_MIN_FOLDS,
    patience=PATIENCE,
    su_filepath=SU_PATH,          # same shared SU matrix — Lympho column already present
    random_seed=RANDOM_SEED,
)

result_reg: WrapperSelectionResult = ws_reg.run(
    n_features_to_select=N_FEATURES,
    test_eval_every_k=TEST_EVAL_EVERY,
)

print()
print(result_reg)
# Out:
# 2026-04-12 20:45:49,298 [INFO] ScoreMatrix: Loaded score matrix from ../data/su_matrix.csv (9266×9266, 85840225 valid entries)
# 2026-04-12 20:45:50,128 [INFO] WrapperSelector: Filter init done in 23.341s | SU target col filled | Mode A | top candidate: CD247 (SU=0.5866)
# 2026-04-12 20:45:50,130 [INFO] WrapperSelector: WrapperSelector initialised | task=regression | use_su_ranking=True | use_mb_pruning=True | mb_threshold=0.0100 | cv_folds=5 | cv_min_folds=3 | patience=None | n_candidates=9264
# 2026-04-12 20:45:50,143 [INFO] WrapperSelector: Step 1 (IWSS): selected 'CD247' mean_cv=0.9170 n_improved=5
# 2026-04-12 20:45:50,150 [INFO] WrapperSelector:   MB pruned 18 candidates
# 2026-04-12 20:45:50,160 [INFO] WrapperSelector: Step 2 (IWSS): selected 'IL2RG' mean_cv=0.9509 n_improved=5
# 2026-04-12 20:45:50,168 [INFO] WrapperSelector:   MB pruned 436 candidates
# 2026-04-12 20:45:50,178 [INFO] WrapperSelector: Step 3 (IWSS): selected 'ACAP1' mean_cv=0.9661 n_improved=5
# 2026-04-12 20:45:50,184 [INFO] WrapperSelector:   MB pruned 10 candidates
# 2026-04-12 20:45:50,192 [INFO] WrapperSelector: Step 4 (IWSS): selected 'MAP4K1' mean_cv=0.9724 n_improved=5
# 2026-04-12 20:45:50,199 [INFO] WrapperSelector:   MB pruned 49 candidates
# 2026-04-12 20:45:50,210 [INFO] WrapperSelector: Step 5 (IWSS): selected 'CD48' mean_cv=0.9755 n_improved=5
# 2026-04-12 20:45:50,218 [INFO] WrapperSelector:   MB pruned 66 candidates
# 2026-04-12 20:45:50,229 [INFO] WrapperSelector: Step 6 (IWSS): selected 'ITK' mean_cv=0.9793 n_improved=5
# 2026-04-12 20:45:50,239 [INFO] WrapperSelector:   MB pruned 11 candidates
# 2026-04-12 20:45:50,253 [INFO] WrapperSelector: Step 7 (IWSS): selected 'LY9' mean_cv=0.9813 n_improved=5
# 2026-04-12 20:45:50,260 [INFO] WrapperSelector:   MB pruned 40 candidates
# 2026-04-12 20:45:50,273 [INFO] WrapperSelector: Step 8 (IWSS): selected 'CD3G' mean_cv=0.9817 n_improved=3
# 2026-04-12 20:45:50,279 [INFO] WrapperSelector:   MB pruned 5 candidates
# 2026-04-12 20:45:50,289 [DEBUG] WrapperSelector:   Candidate 'SIT1' rejected (mean=0.9817 n_imp=3 streak=1)
# 2026-04-12 20:45:50,295 [INFO] WrapperSelector:   Test eval step 8 — r2: 0.9843
# 2026-04-12 20:45:50,308 [INFO] WrapperSelector: Step 9 (IWSS): selected 'SLAMF1' mean_cv=0.9823 n_improved=3
# 2026-04-12 20:45:50,316 [INFO] WrapperSelector:   MB pruned 1 candidates
# 2026-04-12 20:45:50,326 [INFO] WrapperSelector: Step 10 (IWSS): selected 'UBASH3A' mean_cv=0.9824 n_improved=3
# 2026-04-12 20:45:50,334 [INFO] WrapperSelector:   MB pruned 2 candidates
# 2026-04-12 20:45:50,346 [INFO] WrapperSelector: Step 11 (IWSS): selected 'SH2D1A' mean_cv=0.9829 n_improved=3
# 2026-04-12 20:45:50,360 [INFO] WrapperSelector: Step 12 (IWSS): selected 'CD27' mean_cv=0.9834 n_improved=3
# 2026-04-12 20:45:50,369 [INFO] WrapperSelector:   MB pruned 26 candidates
# 2026-04-12 20:45:50,382 [DEBUG] WrapperSelector:   Candidate 'SIRPG' rejected (mean=0.9834 n_imp=2 streak=1)
# 2026-04-12 20:45:50,387 [INFO] WrapperSelector:   Test eval step 12 — r2: 0.9857
# 2026-04-12 20:45:50,398 [INFO] WrapperSelector: Step 13 (IWSS): selected 'PTPN7' mean_cv=0.9839 n_improved=3
# 2026-04-12 20:45:50,405 [INFO] WrapperSelector:   MB pruned 151 candidates
# 2026-04-12 20:45:50,417 [DEBUG] WrapperSelector:   Candidate 'CCL5' rejected (mean=0.9840 n_imp=2 streak=1)
# 2026-04-12 20:45:50,428 [DEBUG] WrapperSelector:   Candidate 'TBX21' rejected (mean=0.9841 n_imp=2 streak=2)
# 2026-04-12 20:45:50,441 [DEBUG] WrapperSelector:   Candidate 'CD6' rejected (mean=0.9839 n_imp=2 streak=3)
# 2026-04-12 20:45:50,452 [INFO] WrapperSelector: Step 14 (IWSS): selected 'IKZF3' mean_cv=0.9841 n_improved=3
# 2026-04-12 20:45:50,459 [INFO] WrapperSelector:   MB pruned 32 candidates
# 2026-04-12 20:45:50,474 [INFO] WrapperSelector: Step 15 (IWSS): selected 'PYHIN1' mean_cv=0.9844 n_improved=4
# 2026-04-12 20:45:50,478 [INFO] WrapperSelector:   MB pruned 1 candidates
# 2026-04-12 20:45:50,490 [DEBUG] WrapperSelector:   Candidate 'NKG7' rejected (mean=0.9847 n_imp=2 streak=1)
# 2026-04-12 20:45:50,504 [INFO] WrapperSelector: Step 16 (IWSS): selected 'PRKCB' mean_cv=0.9866 n_improved=4
# 2026-04-12 20:45:50,511 [INFO] WrapperSelector:   MB pruned 171 candidates
# 2026-04-12 20:45:50,525 [INFO] WrapperSelector: Step 17 (IWSS): selected 'PRF1' mean_cv=0.9873 n_improved=4
# 2026-04-12 20:45:50,532 [INFO] WrapperSelector:   MB pruned 171 candidates
# 2026-04-12 20:45:50,549 [INFO] WrapperSelector: Step 18 (IWSS): selected 'PRKCQ' mean_cv=0.9876 n_improved=3
# 2026-04-12 20:45:50,557 [INFO] WrapperSelector:   MB pruned 167 candidates
# 2026-04-12 20:45:50,573 [INFO] WrapperSelector: Step 19 (IWSS): selected 'TRAT1' mean_cv=0.9876 n_improved=3
# 2026-04-12 20:45:50,580 [INFO] WrapperSelector:   MB pruned 1 candidates
# 2026-04-12 20:45:50,596 [INFO] WrapperSelector: Step 20 (IWSS): selected 'TRAF3IP3' mean_cv=0.9882 n_improved=4
# 2026-04-12 20:45:50,606 [INFO] WrapperSelector:   MB pruned 74 candidates
# 2026-04-12 20:45:50,608 [INFO] WrapperSelector: Selection complete: 20 features | reason=max_features_reached | total_time=23.818s (filter=23.341s clf=0.292s test=0.009s) | cv_evals=26 pruned=1432 skipped=1432
#
# SelectionResult:
#   label             : IWSS-MB
#   features selected : 20
#   task type         : regression
#   stopping reason   : max_features_reached
#   selection time    : 23.818s
#   evaluation time   : 0.009s
#   final R²          : 0.9857060130474464
#   final MSE         : 0.013036263925718897
#   final MAE         : 0.0887306564579286
#   features          : ['CD247', 'IL2RG', 'ACAP1', 'MAP4K1', 'CD48', 'ITK', 'LY9', 'CD3G', 'SLAMF1', 'UBASH3A', 'SH2D1A', 'CD27', 'PTPN7', 'IKZF3', 'PYHIN1', 'PRKCB', 'PRF1', 'PRKCQ', 'TRAT1', 'TRAF3IP3']
#   filter time         : 23.341s
#   classifier time     : 0.292s
#   test eval time      : 0.009s
#   wrapper evaluations : 26
#   candidates pruned   : 1432
#   evaluations skipped : 1432

# %% [markdown]
# ### B.2 — Selected features

# %%
print(f'Regression — {len(result_reg.selected_features)} features selected (in order):')
for i, f in enumerate(result_reg.selected_features, 1):
    print(f'  {i:2d}. {f}')
# Out:
# Regression — 20 features selected (in order):
#    1. CD247
#    2. IL2RG
#    3. ACAP1
#    4. MAP4K1
#    5. CD48
#    6. ITK
#    7. LY9
#    8. CD3G
#    9. SLAMF1
#   10. UBASH3A
#   11. SH2D1A
#   12. CD27
#   13. PTPN7
#   14. IKZF3
#   15. PYHIN1
#   16. PRKCB
#   17. PRF1
#   18. PRKCQ
#   19. TRAT1
#   20. TRAF3IP3

# %% [markdown]
# ### B.3 — LinReg random baseline

# %%
# N_values = number of features selected at each evaluated checkpoint
checkpoints_reg = [entry['step'] for entry in result_reg.performance_history]

baseline_summary_reg = reg_baseline_plot(
    X_train=X_train,
    y_train=y_lympho,
    X_val=X_val,
    y_val=y_lympho_val,
    N_values=checkpoints_reg,
    random_seed=RANDOM_SEED,
    num_runs=N_RUNS,
    return_summary=True,
)
# Out:
# Running LinReg experiments: 100%|██████████| 10/10 [00:00<00:00, 57.25it/s]
# Summary Statistics — Linear Regression Random Baseline (Mean ± Std):
#    features_num   r2_mean    r2_std  mse_mean   mse_std  mae_mean   mae_std
# 0             8  0.337230  0.240140  0.604453  0.219010  0.596585  0.132432
# 1            12  0.381314  0.223988  0.564248  0.204279  0.572678  0.124453

# %% [markdown]
# ### B.4 — Comparison plot

# %%
result_reg.plot_vs_random_baseline(
    baseline_summary=baseline_summary_reg,
    title_suffix=' — SCANB IWSS-MB (Lympho)',
)
# Out:
# Summary Statistics — LinReg Random Baseline (Mean ± Std):
#    features_num   r2_mean    r2_std  mse_mean   mse_std  mae_mean   mae_std
# 0             8  0.337230  0.240140  0.604453  0.219010  0.596585  0.132432
# 1            12  0.381314  0.223988  0.564248  0.204279  0.572678  0.124453

# %% [markdown]
# ---
#
# ## Task C — All four algorithm variants compared (is_lumA, Mode B)
#
# Run all four `WrapperSelector` variants without a precomputed SU file (Mode B —
# lazy incremental column-fill) and compare their performance histories.
#
# | Variant | `use_su_ranking` | `use_mb_pruning` |
# |---------|-----------------|------------------|
# | SFS     | False           | False            |
# | SFS-MB  | False           | True             |
# | IWSS    | True            | False            |
# | IWSS-MB | True            | True             |

# %% [markdown]
# ### C.1 — Run all four variants

# %%
N_COMPARE = 20   # fewer features to keep SFS runtime manageable

variants = [
    ('SFS',     False, False),
    ('SFS-MB',  False, True),
    ('IWSS',    True,  False),
    ('IWSS-MB', True,  True),
]

results_C = {}   # label → WrapperSelectionResult

for label, use_su, use_mb in variants:
    print(f'\n=== {label} (use_su_ranking={use_su}, use_mb_pruning={use_mb}) ===')
    ws = WrapperSelector(
        X_train=X_train,
        y_train=y_lumA,
        X_val=X_val,
        y_val=y_lumA_val,
        use_su_ranking=use_su,
        use_mb_pruning=use_mb,
        mb_threshold=MB_THRESHOLD,
        cv_folds=CV_FOLDS,
        cv_min_folds=CV_MIN_FOLDS,
        patience=PATIENCE,
        # su_filepath=None → Mode B lazy fill
        random_seed=RANDOM_SEED,
    )
    result = ws.run(
        n_features_to_select=N_COMPARE if use_su else 10,
        test_eval_every_k=1,
    )
    results_C[label] = result
    print(f'  Selected: {result.selected_features}')
    print(f'  Stopping: {result.stopping_reason}')
    print(f'  CV evals: {result.n_wrapper_evaluations}  '
          f'Pruned: {result.n_candidates_pruned}  '
          f'Time: {result.selection_time_seconds:.3f}s')
# Out:
# === SFS (use_su_ranking=False, use_mb_pruning=False) ===
# 2026-04-12 20:45:52,016 [INFO] WrapperSelector: WrapperSelector initialised | task=classification | use_su_ranking=False | use_mb_pruning=False | mb_threshold=0.0100 | cv_folds=5 | cv_min_folds=3 | patience=None | n_candidates=9264
# 2026-04-12 20:48:06,505 [INFO] WrapperSelector: Step 1 (SFS): selected 'CCNA2' mean_cv=0.8096
# 2026-04-12 20:48:06,517 [INFO] WrapperSelector:   Test eval step 1 — accuracy: 0.8007
# 2026-04-12 20:50:41,030 [INFO] WrapperSelector: Step 2 (SFS): selected 'MAPT' mean_cv=0.8356
# 2026-04-12 20:50:41,044 [INFO] WrapperSelector:   Test eval step 2 — accuracy: 0.8072
# 2026-04-12 20:53:28,194 [INFO] WrapperSelector: Step 3 (SFS): selected 'CALML3' mean_cv=0.8543
# 2026-04-12 20:53:28,208 [INFO] WrapperSelector:   Test eval step 3 — accuracy: 0.8497
# 2026-04-12 20:56:14,143 [INFO] WrapperSelector: Step 4 (SFS): selected 'PSMC3IP' mean_cv=0.8613
# 2026-04-12 20:56:14,156 [INFO] WrapperSelector:   Test eval step 4 — accuracy: 0.8595
# 2026-04-12 20:59:09,691 [INFO] WrapperSelector: Step 5 (SFS): selected 'PTTG1' mean_cv=0.8687
# 2026-04-12 20:59:09,705 [INFO] WrapperSelector:   Test eval step 5 — accuracy: 0.8497
# 2026-04-12 21:02:57,651 [INFO] WrapperSelector: Step 6 (SFS): selected 'CDC45' mean_cv=0.8748
# 2026-04-12 21:02:57,666 [INFO] WrapperSelector:   Test eval step 6 — accuracy: 0.8627
# 2026-04-12 21:06:56,167 [INFO] WrapperSelector: Step 7 (SFS): selected 'HSD17B11' mean_cv=0.8780
# 2026-04-12 21:06:56,182 [INFO] WrapperSelector:   Test eval step 7 — accuracy: 0.8595
# 2026-04-12 21:10:44,148 [INFO] WrapperSelector: Step 8 (SFS): selected 'TCF7L1' mean_cv=0.8804
# 2026-04-12 21:10:44,164 [INFO] WrapperSelector:   Test eval step 8 — accuracy: 0.8595
# 2026-04-12 21:14:25,413 [INFO] WrapperSelector: Step 9 (SFS): selected 'EP400' mean_cv=0.8817
# 2026-04-12 21:14:25,429 [INFO] WrapperSelector:   Test eval step 9 — accuracy: 0.8595
# 2026-04-12 21:18:24,014 [INFO] WrapperSelector: Step 10 (SFS): selected 'GC' mean_cv=0.8822
# 2026-04-12 21:18:24,030 [INFO] WrapperSelector:   Test eval step 10 — accuracy: 0.8562
# 2026-04-12 21:18:24,031 [INFO] WrapperSelector: Selection complete: 10 features | reason=max_features_reached | total_time=1952.015s (filter=0.000s clf=1951.604s test=0.134s) | cv_evals=92640 pruned=0 skipped=0
#   Selected: ['CCNA2', 'MAPT', 'CALML3', 'PSMC3IP', 'PTTG1', 'CDC45', 'HSD17B11', 'TCF7L1', 'EP400', 'GC']
#   Stopping: max_features_reached
#   CV evals: 92640  Pruned: 0  Time: 1952.015s
#
# === SFS-MB (use_su_ranking=False, use_mb_pruning=True) ===
# 2026-04-12 21:18:25,625 [INFO] ScoreCalculator: init_target complete: method=su, N=9264 features, target=is_lumA
# 2026-04-12 21:18:25,627 [INFO] WrapperSelector: Filter init done in 1.375s | SU target col filled | Mode B | top candidate: A2M (SU=0.2676)
# 2026-04-12 21:18:25,628 [INFO] WrapperSelector: WrapperSelector initialised | task=classification | use_su_ranking=False | use_mb_pruning=True | mb_threshold=0.0100 | cv_folds=5 | cv_min_folds=3 | patience=None | n_candidates=9264
# 2026-04-12 21:20:38,537 [INFO] WrapperSelector: Step 1 (SFS): selected 'CCNA2' mean_cv=0.8096
# 2026-04-12 21:20:38,986 [INFO] WrapperSelector:   MB pruned 1796 candidates
# 2026-04-12 21:20:38,997 [INFO] WrapperSelector:   Test eval step 1 — accuracy: 0.8007
# 2026-04-12 21:22:47,124 [INFO] WrapperSelector: Step 2 (SFS): selected 'MAPT' mean_cv=0.8356
# 2026-04-12 21:22:47,796 [INFO] WrapperSelector:   MB pruned 1964 candidates
# 2026-04-12 21:22:47,812 [INFO] WrapperSelector:   Test eval step 2 — accuracy: 0.8072
# 2026-04-12 21:24:33,149 [INFO] WrapperSelector: Step 3 (SFS): selected 'CALML3' mean_cv=0.8543
# 2026-04-12 21:24:33,607 [INFO] WrapperSelector:   MB pruned 395 candidates
# 2026-04-12 21:24:33,621 [INFO] WrapperSelector:   Test eval step 3 — accuracy: 0.8497
# 2026-04-12 21:26:09,911 [INFO] WrapperSelector: Step 4 (SFS): selected 'PTTG1' mean_cv=0.8594
# 2026-04-12 21:26:10,297 [INFO] WrapperSelector:   MB pruned 367 candidates
# 2026-04-12 21:26:10,313 [INFO] WrapperSelector:   Test eval step 4 — accuracy: 0.8595
# 2026-04-12 21:27:59,981 [INFO] WrapperSelector: Step 5 (SFS): selected 'BIRC5' mean_cv=0.8710
# 2026-04-12 21:28:00,340 [INFO] WrapperSelector:   MB pruned 228 candidates
# 2026-04-12 21:28:00,353 [INFO] WrapperSelector:   Test eval step 5 — accuracy: 0.8693
# 2026-04-12 21:29:51,084 [INFO] WrapperSelector: Step 6 (SFS): selected 'NR1H4' mean_cv=0.8766
# 2026-04-12 21:29:51,391 [INFO] WrapperSelector:   MB pruned 5 candidates
# 2026-04-12 21:29:51,405 [INFO] WrapperSelector:   Test eval step 6 — accuracy: 0.8693
# 2026-04-12 21:31:43,726 [INFO] WrapperSelector: Step 7 (SFS): selected 'TRIM32' mean_cv=0.8804
# 2026-04-12 21:31:43,980 [INFO] WrapperSelector:   MB pruned 285 candidates
# 2026-04-12 21:31:43,993 [INFO] WrapperSelector:   Test eval step 7 — accuracy: 0.8758
# 2026-04-12 21:33:24,670 [INFO] WrapperSelector: Step 8 (SFS): selected 'LYRM2' mean_cv=0.8813
# 2026-04-12 21:33:24,985 [INFO] WrapperSelector:   MB pruned 133 candidates
# 2026-04-12 21:33:24,998 [INFO] WrapperSelector:   Test eval step 8 — accuracy: 0.8758
# 2026-04-12 21:35:05,153 [INFO] WrapperSelector: Step 9 (SFS): selected 'TDRD3' mean_cv=0.8818
# 2026-04-12 21:35:05,390 [INFO] WrapperSelector:   MB pruned 45 candidates
# 2026-04-12 21:35:05,408 [INFO] WrapperSelector:   Test eval step 9 — accuracy: 0.8791
# 2026-04-12 21:36:52,742 [INFO] WrapperSelector: Step 10 (SFS): selected 'SHC1' mean_cv=0.8831
# 2026-04-12 21:36:52,968 [INFO] WrapperSelector:   MB pruned 133 candidates
# 2026-04-12 21:36:52,982 [INFO] WrapperSelector:   Test eval step 10 — accuracy: 0.8725
# 2026-04-12 21:36:52,983 [INFO] WrapperSelector: Selection complete: 10 features | reason=max_features_reached | total_time=1108.728s (filter=1.375s clf=1103.388s test=0.131s) | cv_evals=53426 pruned=5351 skipped=5351
#   Selected: ['CCNA2', 'MAPT', 'CALML3', 'PTTG1', 'BIRC5', 'NR1H4', 'TRIM32', 'LYRM2', 'TDRD3', 'SHC1']
#   Stopping: max_features_reached
#   CV evals: 53426  Pruned: 5351  Time: 1108.728s
#
# === IWSS (use_su_ranking=True, use_mb_pruning=False) ===
# 2026-04-12 21:36:54,559 [INFO] ScoreCalculator: init_target complete: method=su, N=9264 features, target=is_lumA
# 2026-04-12 21:36:54,563 [INFO] WrapperSelector: Filter init done in 1.437s | SU target col filled | Mode B | top candidate: MYBL2 (SU=0.2676)
# 2026-04-12 21:36:54,566 [INFO] WrapperSelector: WrapperSelector initialised | task=classification | use_su_ranking=True | use_mb_pruning=False | mb_threshold=0.0100 | cv_folds=5 | cv_min_folds=3 | patience=None | n_candidates=9264
# 2026-04-12 21:36:54,591 [INFO] WrapperSelector: Step 1 (IWSS): selected 'MYBL2' mean_cv=0.8087 n_improved=5
# 2026-04-12 21:36:54,603 [INFO] WrapperSelector:   Test eval step 1 — accuracy: 0.7778
# 2026-04-12 21:36:54,630 [INFO] WrapperSelector: Step 2 (IWSS): selected 'CDC45' mean_cv=0.8208 n_improved=4
# 2026-04-12 21:36:54,643 [INFO] WrapperSelector:   Test eval step 2 — accuracy: 0.7876
# 2026-04-12 21:36:54,670 [INFO] WrapperSelector: Step 3 (IWSS): selected 'BIRC5' mean_cv=0.8287 n_improved=4
# 2026-04-12 21:36:54,684 [INFO] WrapperSelector:   Test eval step 3 — accuracy: 0.8039
# 2026-04-12 21:36:54,710 [DEBUG] WrapperSelector:   Candidate 'CCNB2' rejected (mean=0.8273 n_imp=3 streak=1)
# 2026-04-12 21:36:54,735 [INFO] WrapperSelector: Step 4 (IWSS): selected 'PTTG1' mean_cv=0.8291 n_improved=3
# 2026-04-12 21:36:54,751 [INFO] WrapperSelector:   Test eval step 4 — accuracy: 0.8105
# 2026-04-12 21:36:54,778 [INFO] WrapperSelector: Step 5 (IWSS): selected 'CENPA' mean_cv=0.8338 n_improved=3
# 2026-04-12 21:36:54,793 [INFO] WrapperSelector:   Test eval step 5 — accuracy: 0.7941
# 2026-04-12 21:36:54,822 [DEBUG] WrapperSelector:   Candidate 'UBE2C' rejected (mean=0.8301 n_imp=2 streak=1)
# 2026-04-12 21:36:54,850 [DEBUG] WrapperSelector:   Candidate 'TPX2' rejected (mean=0.8282 n_imp=1 streak=2)
# 2026-04-12 21:36:54,879 [DEBUG] WrapperSelector:   Candidate 'RRM2' rejected (mean=0.8343 n_imp=2 streak=3)
# 2026-04-12 21:36:54,906 [DEBUG] WrapperSelector:   Candidate 'FOXM1' rejected (mean=0.8287 n_imp=2 streak=4)
# 2026-04-12 21:36:54,935 [INFO] WrapperSelector: Step 6 (IWSS): selected 'AURKA' mean_cv=0.8347 n_improved=3
# 2026-04-12 21:36:54,953 [INFO] WrapperSelector:   Test eval step 6 — accuracy: 0.7941
# 2026-04-12 21:36:54,983 [DEBUG] WrapperSelector:   Candidate 'AURKB' rejected (mean=0.8310 n_imp=2 streak=1)
# 2026-04-12 21:36:55,011 [DEBUG] WrapperSelector:   Candidate 'CCNA2' rejected (mean=0.8287 n_imp=3 streak=2)
# 2026-04-12 21:36:55,040 [DEBUG] WrapperSelector:   Candidate 'TROAP' rejected (mean=0.8301 n_imp=2 streak=3)
# 2026-04-12 21:36:55,069 [INFO] WrapperSelector: Step 7 (IWSS): selected 'SHCBP1' mean_cv=0.8361 n_improved=4
# 2026-04-12 21:36:55,086 [INFO] WrapperSelector:   Test eval step 7 — accuracy: 0.8072
# 2026-04-12 21:36:55,112 [INFO] WrapperSelector: Step 8 (IWSS): selected 'CEP55' mean_cv=0.8385 n_improved=3
# 2026-04-12 21:36:55,126 [INFO] WrapperSelector:   Test eval step 8 — accuracy: 0.8105
# 2026-04-12 21:36:55,154 [DEBUG] WrapperSelector:   Candidate 'KIF2C' rejected (mean=0.8357 n_imp=2 streak=1)
# 2026-04-12 21:36:55,181 [INFO] WrapperSelector: Step 9 (IWSS): selected 'ORC6' mean_cv=0.8408 n_improved=4
# 2026-04-12 21:36:55,193 [INFO] WrapperSelector:   Test eval step 9 — accuracy: 0.8105
# 2026-04-12 21:36:55,225 [DEBUG] WrapperSelector:   Candidate 'CDCA3' rejected (mean=0.8380 n_imp=2 streak=1)
# 2026-04-12 21:36:55,254 [DEBUG] WrapperSelector:   Candidate 'CDKN3' rejected (mean=0.8375 n_imp=2 streak=2)
# 2026-04-12 21:36:55,289 [DEBUG] WrapperSelector:   Candidate 'PLK1' rejected (mean=0.8380 n_imp=3 streak=3)
# 2026-04-12 21:36:55,316 [DEBUG] WrapperSelector:   Candidate 'KIFC1' rejected (mean=0.8371 n_imp=3 streak=4)
# 2026-04-12 21:36:55,343 [DEBUG] WrapperSelector:   Candidate 'CDC25A' rejected (mean=0.8394 n_imp=2 streak=5)
# 2026-04-12 21:36:55,370 [DEBUG] WrapperSelector:   Candidate 'MELK' rejected (mean=0.8380 n_imp=2 streak=6)
# 2026-04-12 21:36:55,402 [DEBUG] WrapperSelector:   Candidate 'CDC20' rejected (mean=0.8380 n_imp=3 streak=7)
# 2026-04-12 21:36:55,436 [DEBUG] WrapperSelector:   Candidate 'SPAG5' rejected (mean=0.8394 n_imp=2 streak=8)
# 2026-04-12 21:36:55,469 [DEBUG] WrapperSelector:   Candidate 'EXO1' rejected (mean=0.8385 n_imp=2 streak=9)
# 2026-04-12 21:36:55,498 [DEBUG] WrapperSelector:   Candidate 'CDCA8' rejected (mean=0.8343 n_imp=2 streak=10)
# 2026-04-12 21:36:55,528 [DEBUG] WrapperSelector:   Candidate 'POLQ' rejected (mean=0.8398 n_imp=3 streak=11)
# 2026-04-12 21:36:55,560 [DEBUG] WrapperSelector:   Candidate 'BUB1' rejected (mean=0.8357 n_imp=2 streak=12)
# 2026-04-12 21:36:55,590 [DEBUG] WrapperSelector:   Candidate 'GTSE1' rejected (mean=0.8389 n_imp=2 streak=13)
# 2026-04-12 21:36:55,617 [DEBUG] WrapperSelector:   Candidate 'TACC3' rejected (mean=0.8375 n_imp=2 streak=14)
# 2026-04-12 21:36:55,647 [DEBUG] WrapperSelector:   Candidate 'KIF4A' rejected (mean=0.8366 n_imp=3 streak=15)
# 2026-04-12 21:36:55,679 [DEBUG] WrapperSelector:   Candidate 'MKI67' rejected (mean=0.8371 n_imp=3 streak=16)
# 2026-04-12 21:36:55,712 [INFO] WrapperSelector: Step 10 (IWSS): selected 'MAD2L1' mean_cv=0.8417 n_improved=3
# 2026-04-12 21:36:55,727 [INFO] WrapperSelector:   Test eval step 10 — accuracy: 0.8007
# 2026-04-12 21:36:55,759 [DEBUG] WrapperSelector:   Candidate 'E2F8' rejected (mean=0.8403 n_imp=2 streak=1)
# 2026-04-12 21:36:55,790 [DEBUG] WrapperSelector:   Candidate 'NDC80' rejected (mean=0.8375 n_imp=2 streak=2)
# 2026-04-12 21:36:55,819 [DEBUG] WrapperSelector:   Candidate 'CENPN' rejected (mean=0.8329 n_imp=2 streak=3)
# 2026-04-12 21:36:55,851 [DEBUG] WrapperSelector:   Candidate 'RAD51' rejected (mean=0.8394 n_imp=3 streak=4)
# 2026-04-12 21:36:55,884 [DEBUG] WrapperSelector:   Candidate 'ORC1' rejected (mean=0.8394 n_imp=2 streak=5)
# 2026-04-12 21:36:55,917 [DEBUG] WrapperSelector:   Candidate 'PRC1' rejected (mean=0.8338 n_imp=2 streak=6)
# 2026-04-12 21:36:55,946 [DEBUG] WrapperSelector:   Candidate 'E2F1' rejected (mean=0.8394 n_imp=3 streak=7)
# 2026-04-12 21:36:55,979 [DEBUG] WrapperSelector:   Candidate 'DLGAP5' rejected (mean=0.8357 n_imp=3 streak=8)
# 2026-04-12 21:36:56,010 [DEBUG] WrapperSelector:   Candidate 'BLM' rejected (mean=0.8361 n_imp=2 streak=9)
# 2026-04-12 21:36:56,044 [DEBUG] WrapperSelector:   Candidate 'NEIL3' rejected (mean=0.8366 n_imp=2 streak=10)
# 2026-04-12 21:36:56,076 [DEBUG] WrapperSelector:   Candidate 'RAD54L' rejected (mean=0.8347 n_imp=1 streak=11)
# 2026-04-12 21:36:56,108 [DEBUG] WrapperSelector:   Candidate 'RAD51AP1' rejected (mean=0.8408 n_imp=3 streak=12)
# 2026-04-12 21:36:56,138 [DEBUG] WrapperSelector:   Candidate 'CCNE1' rejected (mean=0.8384 n_imp=3 streak=13)
# 2026-04-12 21:36:56,172 [DEBUG] WrapperSelector:   Candidate 'RACGAP1' rejected (mean=0.8371 n_imp=3 streak=14)
# 2026-04-12 21:36:56,207 [DEBUG] WrapperSelector:   Candidate 'CENPI' rejected (mean=0.8370 n_imp=2 streak=15)
# 2026-04-12 21:36:56,241 [INFO] WrapperSelector: Step 11 (IWSS): selected 'CCNB1' mean_cv=0.8426 n_improved=3
# 2026-04-12 21:36:56,256 [INFO] WrapperSelector:   Test eval step 11 — accuracy: 0.8072
# 2026-04-12 21:36:56,292 [INFO] WrapperSelector: Step 12 (IWSS): selected 'DDX39A' mean_cv=0.8440 n_improved=3
# 2026-04-12 21:36:56,306 [INFO] WrapperSelector:   Test eval step 12 — accuracy: 0.8039
# 2026-04-12 21:36:56,344 [DEBUG] WrapperSelector:   Candidate 'ASPM' rejected (mean=0.8431 n_imp=3 streak=1)
# 2026-04-12 21:36:56,380 [DEBUG] WrapperSelector:   Candidate 'ESPL1' rejected (mean=0.8422 n_imp=3 streak=2)
# 2026-04-12 21:36:56,416 [DEBUG] WrapperSelector:   Candidate 'KPNA2' rejected (mean=0.8403 n_imp=3 streak=3)
# 2026-04-12 21:36:56,449 [DEBUG] WrapperSelector:   Candidate 'KIF20A' rejected (mean=0.8431 n_imp=3 streak=4)
# 2026-04-12 21:36:56,484 [DEBUG] WrapperSelector:   Candidate 'KIF15' rejected (mean=0.8436 n_imp=3 streak=5)
# 2026-04-12 21:36:56,522 [DEBUG] WrapperSelector:   Candidate 'CDK1' rejected (mean=0.8413 n_imp=3 streak=6)
# 2026-04-12 21:36:56,558 [DEBUG] WrapperSelector:   Candidate 'E2F2' rejected (mean=0.8426 n_imp=3 streak=7)
# 2026-04-12 21:36:56,593 [DEBUG] WrapperSelector:   Candidate 'TTK' rejected (mean=0.8436 n_imp=3 streak=8)
# 2026-04-12 21:36:56,630 [DEBUG] WrapperSelector:   Candidate 'H2AFZ' rejected (mean=0.8426 n_imp=3 streak=9)
# 2026-04-12 21:36:56,663 [DEBUG] WrapperSelector:   Candidate 'LMNB1' rejected (mean=0.8403 n_imp=3 streak=10)
# 2026-04-12 21:36:56,703 [DEBUG] WrapperSelector:   Candidate 'TOP2A' rejected (mean=0.8357 n_imp=2 streak=11)
# 2026-04-12 21:36:56,739 [DEBUG] WrapperSelector:   Candidate 'KIF11' rejected (mean=0.8431 n_imp=3 streak=12)
# 2026-04-12 21:36:56,776 [DEBUG] WrapperSelector:   Candidate 'KIF23' rejected (mean=0.8436 n_imp=3 streak=13)
# 2026-04-12 21:36:56,814 [INFO] WrapperSelector: Step 13 (IWSS): selected 'SPC25' mean_cv=0.8464 n_improved=3
# 2026-04-12 21:36:56,831 [INFO] WrapperSelector:   Test eval step 13 — accuracy: 0.8137
# 2026-04-12 21:36:56,869 [DEBUG] WrapperSelector:   Candidate 'HMMR' rejected (mean=0.8440 n_imp=3 streak=1)
# 2026-04-12 21:36:56,906 [INFO] WrapperSelector: Step 14 (IWSS): selected 'MAPT' mean_cv=0.8571 n_improved=4
# 2026-04-12 21:36:56,927 [INFO] WrapperSelector:   Test eval step 14 — accuracy: 0.8301
# 2026-04-12 21:36:56,963 [DEBUG] WrapperSelector:   Candidate 'CDC25B' rejected (mean=0.8547 n_imp=3 streak=1)
# 2026-04-12 21:36:57,002 [INFO] WrapperSelector: Step 15 (IWSS): selected 'DIAPH3' mean_cv=0.8589 n_improved=3
# 2026-04-12 21:36:57,031 [INFO] WrapperSelector:   Test eval step 15 — accuracy: 0.8301
# 2026-04-12 21:36:57,077 [DEBUG] WrapperSelector:   Candidate 'FEN1' rejected (mean=0.8580 n_imp=3 streak=1)
# 2026-04-12 21:36:57,113 [DEBUG] WrapperSelector:   Candidate 'ERCC6L' rejected (mean=0.8575 n_imp=3 streak=2)
# 2026-04-12 21:36:57,151 [INFO] WrapperSelector: Step 16 (IWSS): selected 'STIL' mean_cv=0.8603 n_improved=3
# 2026-04-12 21:36:57,167 [INFO] WrapperSelector:   Test eval step 16 — accuracy: 0.8301
# 2026-04-12 21:36:57,213 [DEBUG] WrapperSelector:   Candidate 'FANCA' rejected (mean=0.8571 n_imp=3 streak=1)
# 2026-04-12 21:36:57,253 [DEBUG] WrapperSelector:   Candidate 'DONSON' rejected (mean=0.8589 n_imp=3 streak=2)
# 2026-04-12 21:36:57,295 [INFO] WrapperSelector: Step 17 (IWSS): selected 'UBE2S' mean_cv=0.8603 n_improved=3
# 2026-04-12 21:36:57,318 [INFO] WrapperSelector:   Test eval step 17 — accuracy: 0.8301
# 2026-04-12 21:36:57,357 [DEBUG] WrapperSelector:   Candidate 'ASF1B' rejected (mean=0.8594 n_imp=2 streak=1)
# 2026-04-12 21:36:57,398 [DEBUG] WrapperSelector:   Candidate 'MCM6' rejected (mean=0.8566 n_imp=3 streak=2)
# 2026-04-12 21:36:57,439 [INFO] WrapperSelector: Step 18 (IWSS): selected 'MCM2' mean_cv=0.8613 n_improved=3
# 2026-04-12 21:36:57,464 [INFO] WrapperSelector:   Test eval step 18 — accuracy: 0.8301
# 2026-04-12 21:36:57,507 [DEBUG] WrapperSelector:   Candidate 'CENPO' rejected (mean=0.8580 n_imp=3 streak=1)
# 2026-04-12 21:36:57,549 [DEBUG] WrapperSelector:   Candidate 'ZWINT' rejected (mean=0.8603 n_imp=3 streak=2)
# 2026-04-12 21:36:57,591 [INFO] WrapperSelector: Step 19 (IWSS): selected 'TUBA1C' mean_cv=0.8622 n_improved=3
# 2026-04-12 21:36:57,612 [INFO] WrapperSelector:   Test eval step 19 — accuracy: 0.8366
# 2026-04-12 21:36:57,656 [INFO] WrapperSelector: Step 20 (IWSS): selected 'ARHGAP11A' mean_cv=0.8622 n_improved=3
# 2026-04-12 21:36:57,679 [INFO] WrapperSelector:   Test eval step 20 — accuracy: 0.8399
# 2026-04-12 21:36:57,680 [INFO] WrapperSelector: Selection complete: 20 features | reason=max_features_reached | total_time=4.548s (filter=1.437s clf=2.668s test=0.328s) | cv_evals=83 pruned=0 skipped=0
#   Selected: ['MYBL2', 'CDC45', 'BIRC5', 'PTTG1', 'CENPA', 'AURKA', 'SHCBP1', 'CEP55', 'ORC6', 'MAD2L1', 'CCNB1', 'DDX39A', 'SPC25', 'MAPT', 'DIAPH3', 'STIL', 'UBE2S', 'MCM2', 'TUBA1C', 'ARHGAP11A']
#   Stopping: max_features_reached
#   CV evals: 83  Pruned: 0  Time: 4.548s
#
# === IWSS-MB (use_su_ranking=True, use_mb_pruning=True) ===
# 2026-04-12 21:36:59,276 [INFO] ScoreCalculator: init_target complete: method=su, N=9264 features, target=is_lumA
# 2026-04-12 21:36:59,279 [INFO] WrapperSelector: Filter init done in 1.363s | SU target col filled | Mode B | top candidate: MYBL2 (SU=0.2676)
# 2026-04-12 21:36:59,280 [INFO] WrapperSelector: WrapperSelector initialised | task=classification | use_su_ranking=True | use_mb_pruning=True | mb_threshold=0.0100 | cv_folds=5 | cv_min_folds=3 | patience=None | n_candidates=9264
# 2026-04-12 21:36:59,302 [INFO] WrapperSelector: Step 1 (IWSS): selected 'MYBL2' mean_cv=0.8087 n_improved=5
# 2026-04-12 21:36:59,712 [INFO] WrapperSelector:   MB pruned 1707 candidates
# 2026-04-12 21:36:59,731 [INFO] WrapperSelector: Step 2 (IWSS): selected 'MAPT' mean_cv=0.8357 n_improved=5
# 2026-04-12 21:37:00,142 [INFO] WrapperSelector:   MB pruned 1911 candidates
# 2026-04-12 21:37:00,161 [DEBUG] WrapperSelector:   Candidate 'CACNA1D' rejected (mean=0.8352 n_imp=2 streak=1)
# 2026-04-12 21:37:00,171 [INFO] WrapperSelector:   Test eval step 2 — accuracy: 0.8137
# 2026-04-12 21:37:00,191 [INFO] WrapperSelector: Step 3 (IWSS): selected 'SCN2B' mean_cv=0.8426 n_improved=4
# 2026-04-12 21:37:00,497 [INFO] WrapperSelector:   MB pruned 1858 candidates
# 2026-04-12 21:37:00,517 [DEBUG] WrapperSelector:   Candidate 'PTPRT' rejected (mean=0.8440 n_imp=2 streak=1)
# 2026-04-12 21:37:00,529 [INFO] WrapperSelector:   Test eval step 3 — accuracy: 0.8235
# 2026-04-12 21:37:00,549 [DEBUG] WrapperSelector:   Candidate 'FYCO1' rejected (mean=0.8440 n_imp=2 streak=2)
# 2026-04-12 21:37:00,570 [DEBUG] WrapperSelector:   Candidate 'RANBP1' rejected (mean=0.8389 n_imp=3 streak=3)
# 2026-04-12 21:37:00,594 [INFO] WrapperSelector: Step 4 (IWSS): selected 'MATN3' mean_cv=0.8464 n_improved=3
# 2026-04-12 21:37:00,755 [INFO] WrapperSelector:   MB pruned 140 candidates
# 2026-04-12 21:37:00,776 [DEBUG] WrapperSelector:   Candidate 'ARHGAP35' rejected (mean=0.8459 n_imp=3 streak=1)
# 2026-04-12 21:37:00,788 [INFO] WrapperSelector:   Test eval step 4 — accuracy: 0.8268
# 2026-04-12 21:37:00,810 [INFO] WrapperSelector: Step 5 (IWSS): selected 'ALAD' mean_cv=0.8468 n_improved=3
# 2026-04-12 21:37:00,976 [INFO] WrapperSelector:   MB pruned 310 candidates
# 2026-04-12 21:37:01,002 [DEBUG] WrapperSelector:   Candidate 'SIRT3' rejected (mean=0.8454 n_imp=3 streak=1)
# 2026-04-12 21:37:01,021 [INFO] WrapperSelector:   Test eval step 5 — accuracy: 0.8105
# 2026-04-12 21:37:01,051 [INFO] WrapperSelector: Step 6 (IWSS): selected 'RAI2' mean_cv=0.8473 n_improved=3
# 2026-04-12 21:37:01,250 [INFO] WrapperSelector:   MB pruned 61 candidates
# 2026-04-12 21:37:01,275 [INFO] WrapperSelector: Step 7 (IWSS): selected 'JMJD6' mean_cv=0.8492 n_improved=3
# 2026-04-12 21:37:01,430 [INFO] WrapperSelector:   MB pruned 115 candidates
# 2026-04-12 21:37:01,456 [INFO] WrapperSelector: Step 8 (IWSS): selected 'DOCK1' mean_cv=0.8492 n_improved=3
# 2026-04-12 21:37:01,614 [INFO] WrapperSelector:   MB pruned 403 candidates
# 2026-04-12 21:37:01,639 [DEBUG] WrapperSelector:   Candidate 'TOM1L2' rejected (mean=0.8450 n_imp=2 streak=1)
# 2026-04-12 21:37:01,651 [INFO] WrapperSelector:   Test eval step 8 — accuracy: 0.8301
# 2026-04-12 21:37:01,682 [DEBUG] WrapperSelector:   Candidate 'RUNX1' rejected (mean=0.8464 n_imp=3 streak=2)
# 2026-04-12 21:37:01,710 [INFO] WrapperSelector: Step 9 (IWSS): selected 'UQCRH' mean_cv=0.8496 n_improved=3
# 2026-04-12 21:37:01,889 [INFO] WrapperSelector:   MB pruned 115 candidates
# 2026-04-12 21:37:01,911 [INFO] WrapperSelector: Step 10 (IWSS): selected 'IGFALS' mean_cv=0.8520 n_improved=3
# 2026-04-12 21:37:02,049 [INFO] WrapperSelector:   MB pruned 123 candidates
# 2026-04-12 21:37:02,071 [DEBUG] WrapperSelector:   Candidate 'GLT8D1' rejected (mean=0.8524 n_imp=2 streak=1)
# 2026-04-12 21:37:02,084 [INFO] WrapperSelector:   Test eval step 10 — accuracy: 0.8366
# 2026-04-12 21:37:02,110 [DEBUG] WrapperSelector:   Candidate 'TDO2' rejected (mean=0.8529 n_imp=2 streak=2)
# 2026-04-12 21:37:02,134 [DEBUG] WrapperSelector:   Candidate 'PTGER3' rejected (mean=0.8510 n_imp=3 streak=3)
# 2026-04-12 21:37:02,161 [DEBUG] WrapperSelector:   Candidate 'SEZ6L' rejected (mean=0.8506 n_imp=2 streak=4)
# 2026-04-12 21:37:02,190 [DEBUG] WrapperSelector:   Candidate 'WDR78' rejected (mean=0.8510 n_imp=2 streak=5)
# 2026-04-12 21:37:02,213 [INFO] WrapperSelector: Step 11 (IWSS): selected 'TIGD6' mean_cv=0.8534 n_improved=3
# 2026-04-12 21:37:02,380 [INFO] WrapperSelector:   MB pruned 272 candidates
# 2026-04-12 21:37:02,406 [DEBUG] WrapperSelector:   Candidate 'ASNS' rejected (mean=0.8520 n_imp=3 streak=1)
# 2026-04-12 21:37:02,417 [INFO] WrapperSelector:   Test eval step 11 — accuracy: 0.8366
# 2026-04-12 21:37:02,440 [DEBUG] WrapperSelector:   Candidate 'MTHFR' rejected (mean=0.8529 n_imp=4 streak=2)
# 2026-04-12 21:37:02,461 [DEBUG] WrapperSelector:   Candidate 'PIR' rejected (mean=0.8501 n_imp=2 streak=3)
# 2026-04-12 21:37:02,484 [INFO] WrapperSelector: Step 12 (IWSS): selected 'KLHL9' mean_cv=0.8538 n_improved=3
# 2026-04-12 21:37:02,630 [INFO] WrapperSelector:   MB pruned 96 candidates
# 2026-04-12 21:37:02,654 [DEBUG] WrapperSelector:   Candidate 'POU4F1' rejected (mean=0.8533 n_imp=3 streak=1)
# 2026-04-12 21:37:02,665 [INFO] WrapperSelector:   Test eval step 12 — accuracy: 0.8366
# 2026-04-12 21:37:02,698 [DEBUG] WrapperSelector:   Candidate 'DEK' rejected (mean=0.8482 n_imp=1 streak=2)
# 2026-04-12 21:37:02,722 [INFO] WrapperSelector: Step 13 (IWSS): selected 'ARHGEF38' mean_cv=0.8557 n_improved=3
# 2026-04-12 21:37:02,831 [INFO] WrapperSelector:   MB pruned 103 candidates
# 2026-04-12 21:37:02,854 [DEBUG] WrapperSelector:   Candidate 'ZNF219' rejected (mean=0.8547 n_imp=2 streak=1)
# 2026-04-12 21:37:02,866 [INFO] WrapperSelector:   Test eval step 13 — accuracy: 0.8366
# 2026-04-12 21:37:02,893 [INFO] WrapperSelector: Step 14 (IWSS): selected 'BTD' mean_cv=0.8571 n_improved=3
# 2026-04-12 21:37:03,030 [INFO] WrapperSelector:   MB pruned 48 candidates
# 2026-04-12 21:37:03,056 [DEBUG] WrapperSelector:   Candidate 'ZBTB40' rejected (mean=0.8557 n_imp=3 streak=1)
# 2026-04-12 21:37:03,075 [INFO] WrapperSelector:   Test eval step 14 — accuracy: 0.8333
# 2026-04-12 21:37:03,108 [DEBUG] WrapperSelector:   Candidate 'SPTAN1' rejected (mean=0.8566 n_imp=3 streak=2)
# 2026-04-12 21:37:03,139 [DEBUG] WrapperSelector:   Candidate 'SLC44A4' rejected (mean=0.8561 n_imp=2 streak=3)
# 2026-04-12 21:37:03,172 [DEBUG] WrapperSelector:   Candidate 'NBEA' rejected (mean=0.8561 n_imp=2 streak=4)
# 2026-04-12 21:37:03,203 [DEBUG] WrapperSelector:   Candidate 'ATP7B' rejected (mean=0.8557 n_imp=3 streak=5)
# 2026-04-12 21:37:03,235 [DEBUG] WrapperSelector:   Candidate 'HPSE' rejected (mean=0.8547 n_imp=1 streak=6)
# 2026-04-12 21:37:03,266 [DEBUG] WrapperSelector:   Candidate 'CCNG2' rejected (mean=0.8543 n_imp=1 streak=7)
# 2026-04-12 21:37:03,298 [DEBUG] WrapperSelector:   Candidate 'TBC1D17' rejected (mean=0.8561 n_imp=2 streak=8)
# 2026-04-12 21:37:03,331 [DEBUG] WrapperSelector:   Candidate 'ME2' rejected (mean=0.8529 n_imp=1 streak=9)
# 2026-04-12 21:37:03,362 [DEBUG] WrapperSelector:   Candidate 'PCSK6' rejected (mean=0.8552 n_imp=3 streak=10)
# 2026-04-12 21:37:03,394 [INFO] WrapperSelector: Step 15 (IWSS): selected 'ARHGAP32' mean_cv=0.8580 n_improved=3
# 2026-04-12 21:37:03,474 [INFO] WrapperSelector:   MB pruned 26 candidates
# 2026-04-12 21:37:03,505 [DEBUG] WrapperSelector:   Candidate 'PDIA6' rejected (mean=0.8571 n_imp=3 streak=1)
# 2026-04-12 21:37:03,524 [INFO] WrapperSelector:   Test eval step 15 — accuracy: 0.8431
# 2026-04-12 21:37:03,561 [DEBUG] WrapperSelector:   Candidate 'RERE' rejected (mean=0.8566 n_imp=2 streak=2)
# 2026-04-12 21:37:03,599 [DEBUG] WrapperSelector:   Candidate 'AARS' rejected (mean=0.8580 n_imp=2 streak=3)
# 2026-04-12 21:37:03,630 [DEBUG] WrapperSelector:   Candidate 'BTG2' rejected (mean=0.8575 n_imp=3 streak=4)
# 2026-04-12 21:37:03,658 [DEBUG] WrapperSelector:   Candidate 'TMSB15A' rejected (mean=0.8585 n_imp=2 streak=5)
# 2026-04-12 21:37:03,690 [INFO] WrapperSelector: Step 16 (IWSS): selected 'SLC25A13' mean_cv=0.8599 n_improved=3
# 2026-04-12 21:37:03,764 [INFO] WrapperSelector:   MB pruned 46 candidates
# 2026-04-12 21:37:03,794 [INFO] WrapperSelector: Step 17 (IWSS): selected 'TBC1D19' mean_cv=0.8603 n_improved=3
# 2026-04-12 21:37:03,867 [INFO] WrapperSelector:   MB pruned 11 candidates
# 2026-04-12 21:37:03,894 [DEBUG] WrapperSelector:   Candidate 'IMPA2' rejected (mean=0.8575 n_imp=2 streak=1)
# 2026-04-12 21:37:03,909 [INFO] WrapperSelector:   Test eval step 17 — accuracy: 0.8399
# 2026-04-12 21:37:03,940 [DEBUG] WrapperSelector:   Candidate 'DUSP4' rejected (mean=0.8589 n_imp=2 streak=2)
# 2026-04-12 21:37:03,968 [INFO] WrapperSelector: Step 18 (IWSS): selected 'TECPR2' mean_cv=0.8617 n_improved=3
# 2026-04-12 21:37:04,038 [INFO] WrapperSelector:   MB pruned 21 candidates
# 2026-04-12 21:37:04,068 [DEBUG] WrapperSelector:   Candidate 'ENO1' rejected (mean=0.8613 n_imp=2 streak=1)
# 2026-04-12 21:37:04,081 [INFO] WrapperSelector:   Test eval step 18 — accuracy: 0.8399
# 2026-04-12 21:37:04,110 [INFO] WrapperSelector: Step 19 (IWSS): selected 'VIPR2' mean_cv=0.8617 n_improved=3
# 2026-04-12 21:37:04,178 [INFO] WrapperSelector:   MB pruned 48 candidates
# 2026-04-12 21:37:04,205 [DEBUG] WrapperSelector:   Candidate 'PPP1R3C' rejected (mean=0.8585 n_imp=2 streak=1)
# 2026-04-12 21:37:04,222 [INFO] WrapperSelector:   Test eval step 19 — accuracy: 0.8464
# 2026-04-12 21:37:04,249 [DEBUG] WrapperSelector:   Candidate 'WDTC1' rejected (mean=0.8603 n_imp=3 streak=2)
# 2026-04-12 21:37:04,278 [INFO] WrapperSelector: Step 20 (IWSS): selected 'GARS' mean_cv=0.8622 n_improved=3
# 2026-04-12 21:37:04,345 [INFO] WrapperSelector:   MB pruned 39 candidates
# 2026-04-12 21:37:04,346 [INFO] WrapperSelector: Selection complete: 20 features | reason=max_features_reached | total_time=6.427s (filter=1.363s clf=1.526s test=0.180s) | cv_evals=59 pruned=7453 skipped=7453
#   Selected: ['MYBL2', 'MAPT', 'SCN2B', 'MATN3', 'ALAD', 'RAI2', 'JMJD6', 'DOCK1', 'UQCRH', 'IGFALS', 'TIGD6', 'KLHL9', 'ARHGEF38', 'BTD', 'ARHGAP32', 'SLC25A13', 'TBC1D19', 'TECPR2', 'VIPR2', 'GARS']
#   Stopping: max_features_reached
#   CV evals: 59  Pruned: 7453  Time: 6.427s

# %% [markdown]
# ### C.2 — Timing and efficiency comparison table

# %%
timing_rows = []
for label, res in results_C.items():
    timing_rows.append({
        'variant': label,
        'features_selected': len(res.selected_features),
        'stopping_reason': res.stopping_reason,
        'total_time_s': round(res.selection_time_seconds, 4),
        'filter_time_s': round(res.filter_time_seconds, 4),
        'clf_time_s': round(res.classifier_time_seconds, 4),
        'cv_evaluations': res.n_wrapper_evaluations,
        'pruned': res.n_candidates_pruned,
        'skipped_evals': res.n_evaluations_skipped,
    })

timing_df = pd.DataFrame(timing_rows).set_index('variant')
print('Algorithm variant comparison:')
display(timing_df)
# Out:
# Algorithm variant comparison:
#          features_selected       stopping_reason  total_time_s  filter_time_s  \
# variant
# SFS                     10  max_features_reached     1952.0146         0.0000
# SFS-MB                  10  max_features_reached     1108.7280         1.3751
# IWSS                    20  max_features_reached        4.5477         1.4367
# IWSS-MB                 20  max_features_reached        6.4267         1.3635
#
#          clf_time_s  cv_evaluations  pruned  skipped_evals
# variant
# SFS       1951.6036           92640       0              0
# SFS-MB    1103.3877           53426    5351           5351
# IWSS         2.6677              83       0              0
# IWSS-MB      1.5257              59    7453           7453

# %% [markdown]
# ### C.3 — Evaluator-call count and timing bar charts

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

variants_order = list(results_C.keys())
eval_counts  = [results_C[v].n_wrapper_evaluations for v in variants_order]
total_times  = [results_C[v].selection_time_seconds for v in variants_order]

ax = axes[0]
bars = ax.bar(variants_order, eval_counts, color='steelblue', alpha=0.85)
ax.bar_label(bars, padding=3, fontsize=9)
ax.set_title('Evaluator calls per variant', fontsize=12)
ax.set_ylabel('CV evaluations')
ax.grid(True, axis='y', alpha=0.4)

ax = axes[1]
bars = ax.bar(variants_order, total_times, color='darkorange', alpha=0.85)
ax.bar_label(bars, fmt='{:.2f}s', padding=3, fontsize=9)
ax.set_title('Total selection time per variant', fontsize=12)
ax.set_ylabel('Time (s)')
ax.grid(True, axis='y', alpha=0.4)

fig.suptitle(
    f'Task C — All variants, Mode B — SCANB (is_lumA, {N_COMPARE} features)',
    fontsize=13, fontweight='bold',
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### C.4 — Performance comparison plot

# %%
# Only compare results that have performance history entries
valid_results = {k: v for k, v in results_C.items() if v.performance_history}

if valid_results:
    SelectionResult.compare_results(
        results=list(valid_results.values()),
        labels=list(valid_results.keys()),
        baseline_summary=baseline_summary_clf,
        title_suffix=' — SCANB (is_lumA, Mode B)',
    )
else:
    print('No results with performance history to compare.')

# %% [markdown]
# ### C.5 — Feature diff: IWSS vs IWSS-MB

# %%
if 'IWSS' in results_C and 'IWSS-MB' in results_C:
    results_C['IWSS'].compare_with(
        results_C['IWSS-MB'],
        self_label='IWSS',
        other_label='IWSS-MB',
    )
else:
    print('IWSS or IWSS-MB result not available.')
# Out:
# Comparing IWSS (N=20) vs IWSS-MB (N=20)
# ──────┼───────────┼───────────
# rank │ IWSS      │ IWSS-MB
# ──────┼───────────┼───────────
#    1 │ MYBL2     │ MYBL2
#    2 │ CDC45     │ MAPT
#    3 │ BIRC5     │ SCN2B
#    4 │ PTTG1     │ MATN3
#    5 │ CENPA     │ ALAD
#    6 │ AURKA     │ RAI2
#    7 │ SHCBP1    │ JMJD6
#    8 │ CEP55     │ DOCK1
#    9 │ ORC6      │ UQCRH
#   10 │ MAD2L1    │ IGFALS
#   11 │ CCNB1     │ TIGD6
#   12 │ DDX39A    │ KLHL9
#   13 │ SPC25     │ ARHGEF38
#   14 │ MAPT      │ BTD
#   15 │ DIAPH3    │ ARHGAP32
#   16 │ STIL      │ SLC25A13
#   17 │ UBE2S     │ TBC1D19
#   18 │ MCM2      │ TECPR2
#   19 │ TUBA1C    │ VIPR2
#   20 │ ARHGAP11A │ GARS
# ──────┼───────────┼───────────
# ■ same rank  ■ diff rank  ■ one result only  — beyond result length

# %%
if 'SFS' in results_C and 'SFS-MB' in results_C:
    results_C['SFS'].compare_with(
        results_C['SFS-MB'],
        self_label='SFS',
        other_label='SFS-MB',
    )
else:
    print('SFS or SFS-MB result not available.')
# Out:
# Comparing SFS (N=10) vs SFS-MB (N=10)
# ──────┼──────────┼──────────
# rank │ SFS      │ SFS-MB
# ──────┼──────────┼──────────
#    1 │ CCNA2    │ CCNA2
#    2 │ MAPT     │ MAPT
#    3 │ CALML3   │ CALML3
#    4 │ PSMC3IP  │ PTTG1
#    5 │ PTTG1    │ BIRC5
#    6 │ CDC45    │ NR1H4
#    7 │ HSD17B11 │ TRIM32
#    8 │ TCF7L1   │ LYRM2
#    9 │ EP400    │ TDRD3
#   10 │ GC       │ SHC1
# ──────┼──────────┼──────────
# ■ same rank  ■ diff rank  ■ one result only  — beyond result length

# %%
if 'SFS' in results_C and 'IWSS-MB' in results_C:
    results_C['SFS'].compare_with(
        results_C['IWSS-MB'],
        self_label='SFS',
        other_label='IWSS-MB',
    )
else:
    print('SFS or IWSS-MB result not available.')
# Out:
# Comparing SFS (N=10) vs IWSS-MB (N=20)
# ──────┼──────────┼──────────
# rank │ SFS      │ IWSS-MB
# ──────┼──────────┼──────────
#    1 │ CCNA2    │ MYBL2
#    2 │ MAPT     │ MAPT
#    3 │ CALML3   │ SCN2B
#    4 │ PSMC3IP  │ MATN3
#    5 │ PTTG1    │ ALAD
#    6 │ CDC45    │ RAI2
#    7 │ HSD17B11 │ JMJD6
#    8 │ TCF7L1   │ DOCK1
#    9 │ EP400    │ UQCRH
#   10 │ GC       │ IGFALS
#   11 │ —        │ TIGD6
#   12 │ —        │ KLHL9
#   13 │ —        │ ARHGEF38
#   14 │ —        │ BTD
#   15 │ —        │ ARHGAP32
#   16 │ —        │ SLC25A13
#   17 │ —        │ TBC1D19
#   18 │ —        │ TECPR2
#   19 │ —        │ VIPR2
#   20 │ —        │ GARS
# ──────┼──────────┼──────────
# ■ same rank  ■ diff rank  ■ one result only  — beyond result length

# %% [markdown]
# ### C.6 — Summary report: all four variants

# %%
summary_df = SelectionResult.summary_report(
    results=list(results_C.values()),
    labels=list(results_C.keys()),
)
# Out:
# Feature summary across 4 results (50 unique features):
# Labels: SFS, SFS-MB, IWSS, IWSS-MB
#       feature  count    pct  mean_rank  min_rank  max_rank  \
# 0        MAPT      4  100.0       5.00         2        14
# 1       PTTG1      3   75.0       4.33         4         5
# 2       CCNA2      2   50.0       1.00         1         1
# 3       MYBL2      2   50.0       1.00         1         1
# 4      CALML3      2   50.0       3.00         3         3
# 5       CDC45      2   50.0       4.00         2         6
# 6       BIRC5      2   50.0       4.00         3         5
# 7       SCN2B      1   25.0       3.00         3         3
# 8     PSMC3IP      1   25.0       4.00         4         4
# 9       MATN3      1   25.0       4.00         4         4
# 10      CENPA      1   25.0       5.00         5         5
# 11       ALAD      1   25.0       5.00         5         5
# 12      NR1H4      1   25.0       6.00         6         6
# 13      AURKA      1   25.0       6.00         6         6
# 14       RAI2      1   25.0       6.00         6         6
# 15   HSD17B11      1   25.0       7.00         7         7
# 16     TRIM32      1   25.0       7.00         7         7
# 17     SHCBP1      1   25.0       7.00         7         7
# 18      JMJD6      1   25.0       7.00         7         7
# 19     TCF7L1      1   25.0       8.00         8         8
# 20      LYRM2      1   25.0       8.00         8         8
# 21      CEP55      1   25.0       8.00         8         8
# 22      DOCK1      1   25.0       8.00         8         8
# 23      EP400      1   25.0       9.00         9         9
# 24      TDRD3      1   25.0       9.00         9         9
# 25       ORC6      1   25.0       9.00         9         9
# 26      UQCRH      1   25.0       9.00         9         9
# 27         GC      1   25.0      10.00        10        10
# 28       SHC1      1   25.0      10.00        10        10
# 29     MAD2L1      1   25.0      10.00        10        10
# 30     IGFALS      1   25.0      10.00        10        10
# 31      CCNB1      1   25.0      11.00        11        11
# 32      TIGD6      1   25.0      11.00        11        11
# 33     DDX39A      1   25.0      12.00        12        12
# 34      KLHL9      1   25.0      12.00        12        12
# 35      SPC25      1   25.0      13.00        13        13
# 36   ARHGEF38      1   25.0      13.00        13        13
# 37        BTD      1   25.0      14.00        14        14
# 38     DIAPH3      1   25.0      15.00        15        15
# 39   ARHGAP32      1   25.0      15.00        15        15
# 40       STIL      1   25.0      16.00        16        16
# 41   SLC25A13      1   25.0      16.00        16        16
# 42      UBE2S      1   25.0      17.00        17        17
# 43    TBC1D19      1   25.0      17.00        17        17
# 44       MCM2      1   25.0      18.00        18        18
# 45     TECPR2      1   25.0      18.00        18        18
# 46     TUBA1C      1   25.0      19.00        19        19
# 47      VIPR2      1   25.0      19.00        19        19
# 48  ARHGAP11A      1   25.0      20.00        20        20
# 49       GARS      1   25.0      20.00        20        20
#
#                    selected_by
# 0   IWSS-MB, SFS, SFS-MB, IWSS
# 1            IWSS, SFS-MB, SFS
# 2                  SFS, SFS-MB
# 3                IWSS, IWSS-MB
# 4                  SFS, SFS-MB
# 5                    IWSS, SFS
# 6                 IWSS, SFS-MB
# 7                      IWSS-MB
# 8                          SFS
# 9                      IWSS-MB
# 10                        IWSS
# 11                     IWSS-MB
# 12                      SFS-MB
# 13                        IWSS
# 14                     IWSS-MB
# 15                         SFS
# 16                      SFS-MB
# 17                        IWSS
# 18                     IWSS-MB
# 19                         SFS
# 20                      SFS-MB
# 21                        IWSS
# 22                     IWSS-MB
# 23                         SFS
# 24                      SFS-MB
# 25                        IWSS
# 26                     IWSS-MB
# 27                         SFS
# 28                      SFS-MB
# 29                        IWSS
# 30                     IWSS-MB
# 31                        IWSS
# 32                     IWSS-MB
# 33                        IWSS
# 34                     IWSS-MB
# 35                        IWSS
# 36                     IWSS-MB
# 37                     IWSS-MB
# 38                        IWSS
# 39                     IWSS-MB
# 40                        IWSS
# 41                     IWSS-MB
# 42                        IWSS
# 43                     IWSS-MB
# 44                        IWSS
# 45                     IWSS-MB
# 46                        IWSS
# 47                     IWSS-MB
# 48                        IWSS
# 49                     IWSS-MB

# %% [markdown]
# ---
#
# ## Summary — Timing across all tasks

# %%
print('=== Task A — Classification IWSS-MB (is_lumA, Mode A) ===')
print(f'  Features selected    : {len(result_clf.selected_features)}')
print(f'  Total time           : {result_clf.selection_time_seconds:.3f}s')
print(f'    └─ Filter init     : {result_clf.filter_time_seconds:.3f}s')
print(f'    └─ Evaluator CV    : {result_clf.classifier_time_seconds:.3f}s')
print(f'  Test eval time (val) : {result_clf.test_evaluation_time_seconds:.3f}s')
print(f'  CV evaluations       : {result_clf.n_wrapper_evaluations}')
print(f'  Candidates pruned    : {result_clf.n_candidates_pruned}')
print(f'  Stopping reason      : {result_clf.stopping_reason}')

print()
print('=== Task B — Regression IWSS-MB (Lympho, Mode A) ===')
print(f'  Features selected    : {len(result_reg.selected_features)}')
print(f'  Total time           : {result_reg.selection_time_seconds:.3f}s')
print(f'    └─ Filter init     : {result_reg.filter_time_seconds:.3f}s')
print(f'    └─ Evaluator CV    : {result_reg.classifier_time_seconds:.3f}s')
print(f'  Test eval time (val) : {result_reg.test_evaluation_time_seconds:.3f}s')
print(f'  CV evaluations       : {result_reg.n_wrapper_evaluations}')
print(f'  Candidates pruned    : {result_reg.n_candidates_pruned}')
print(f'  Stopping reason      : {result_reg.stopping_reason}')

print()
print('=== Task C — All four variants (is_lumA, Mode B) ===')
display(timing_df)
# Out:
# === Task A — Classification IWSS-MB (is_lumA, Mode A) ===
#   Features selected    : 20
#   Total time           : 22.582s
#     └─ Filter init     : 20.761s
#     └─ Evaluator CV    : 1.569s
#   Test eval time (val) : 0.109s
#   CV evaluations       : 59
#   Candidates pruned    : 7453
#   Stopping reason      : max_features_reached
#
# === Task B — Regression IWSS-MB (Lympho, Mode A) ===
#   Features selected    : 20
#   Total time           : 23.818s
#     └─ Filter init     : 23.341s
#     └─ Evaluator CV    : 0.292s
#   Test eval time (val) : 0.009s
#   CV evaluations       : 26
#   Candidates pruned    : 1432
#   Stopping reason      : max_features_reached
#
# === Task C — All four variants (is_lumA, Mode B) ===
#          features_selected       stopping_reason  total_time_s  filter_time_s  \
# variant
# SFS                     10  max_features_reached     1952.0146         0.0000
# SFS-MB                  10  max_features_reached     1108.7280         1.3751
# IWSS                    20  max_features_reached        4.5477         1.4367
# IWSS-MB                 20  max_features_reached        6.4267         1.3635
#
#          clf_time_s  cv_evaluations  pruned  skipped_evals
# variant
# SFS       1951.6036           92640       0              0
# SFS-MB    1103.3877           53426    5351           5351
# IWSS         2.6677              83       0              0
# IWSS-MB      1.5257              59    7453           7453
